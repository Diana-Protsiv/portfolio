# %% [markdown]
# <div style="border:solid Chocolate 2px; padding: 40px">
#
# <b>Диана, приветствую!</b>
#
# Буду рада с тобой познакомиться. Меня зовут Евгения Маракова и я буду ревьюером твоего проекта. Если ты не против, то предлагаю общаться на "ты":) Если удобнее на "вы", то нет проблем, только скажи об этом.
#
# В процессе работы ты встретишь комментарии <font color='green'>зеленого</font>, <font color='gold'>желтого</font> и <font color='red'>красного</font> цветов. Что они значат, смотри ниже:
#     <br/>
#
# <div class="alert alert-success">
# <h2> Комментарий ревьюера <a class="tocSkip"> </h2>
#
# <b>Отлично!✅:</b> Решение на этом шаге является полностью правильным. У тебя хорошо получается проводить АВ-тестирование и анализировать данные!
# </div>
#
# <br/>
#
# <div class="alert alert-warning">
#     <h2> Комментарий ревьюера <a class="tocSkip"> </h2>
#
# <b>Можно лучше⚠️:</b> Решение на этом шаге станет еще лучше, если внести небольшие коррективы.
# </div>
#
#
# <br/>
# <div class="alert alert-block alert-danger">
# <h2> Комментарий ревьюера <a class="tocSkip"></h2>
#
#
# <b>Необходимо исправить❌:</b>
#  Решение на этом шаге требует существенной переработки и внесения правок. Напоминаю, что проект не может быть принят с первого раза, если ревью содержит комментарии, рекомендующие доработать шаги.
# </div>
#
# Увидев мой комментарий, не удаляй его, он будет очень полезен в случае повторной проверки работы😊
#
# Свой комментарий помечай так, как показано ниже, тогда нам будет легче вести диалог, а мне выполнить повторную проверку проекта.
#     <div class="alert alert-info"> <b>Комментарий студента: </b> </div>

# %% [markdown]
# # Приоритизация гипотез по увеличению выручки интернет-магазина и анализ A/B-теста

# %% [markdown]
# В основе исследования крупного интернет-магазина лежат гипотезы для увеличения его выручки.
#
# **Цель исследования** — приоритизировать гипотезы по увеличению выручки интернет-магазина, запустить A/B-тест и проанализировать результаты.

# %% [markdown]
# **Описание данных**
#
# 9 гипотез по увеличению выручки интернет-магазина с указанными параметрами Reach, Impact, Confidence, Effort.
#
# Гипотезы:
#
# - `Hypothesis` — краткое описание гипотезы
#
# - `Reach` — охват пользователей по 10-балльной шкале
#
# - `Impact` — влияние на пользователей по 10-балльной шкале
#
# - `Confidence` — уверенность в гипотезе по 10-балльной шкале
#
# - `Efforts` — затраты ресурсов на проверку гипотезы по 10-балльной шкале
#
# Чем больше значение `Efforts`, тем дороже проверка гипотезы.
#
# Заказы:
#
# - `transactionId` — идентификатор заказа
#
# - `visitorId` — идентификатор пользователя, совершившего заказ
#
# - `date` — дата, когда был совершён заказ
#
# - `revenue` — выручка заказа
#
# - `group` — группа A/B-теста, в которую попал заказ (A или B)
#
# Посетители:
#
# - `date` — дата
#
# - `group` — группа A/B-теста (A или B)
#
# - `visitors` — количество пользователей в указанную дату в указанной группе A/B-теста

# %% [markdown]
# **План работы**
#
# 1. Загрузка и предобработка данных:
# - загрузка данных о гипотезах, заказах и пользователях из CSV-файлов в переменные;
# - вывод первых строк каждого набора данных;
# - изучение общей информации о датафреймах;
# - поиск пропущенных значений и дубликатов в данных;
# - замена названий столбцов датафреймов;
# - преобразование данных в нужные типы.
#
# 2. Приоритизация гипотез:
# - применение фреймворка ICE для приоритизации гипотез, сортировка их по убыванию приоритета;
# - применение фреймворка RICE для приоритизации гипотез, сортировка их по убыванию приоритета;
# - анализ изменения приоритизации гипотез при применении RICE вместо ICE.
#
# 3. Анализ A/B-теста:
# - построение графика кумулятивной выручки по группам, написание выводов и предположений;
# - построение графика кумулятивного среднего чека по группам, написание выводов и предположений;
# - построение графика относительного изменения кумулятивного среднего чека группы B к группе A, написание выводов и предположений;
# - построение графика кумулятивного среднего количества заказов на посетителя по группам, написание выводов и предположений;
# - построение графика относительного изменения кумулятивного среднего количества заказов на посетителя группы B к группе A, написание выводов и предположений;
# - построение точечного графика количества заказов по пользователям, написание выводов и предположений;
# - подсчёт 95-го и 99-го перцентилей количества заказов на пользователя, выбор границы для определения аномальных пользователей;
# - построение точечного графика стоимостей заказов, написание выводов и предположений;
# - подсчёт 95-го и 99-го перцентилей стоимости заказов, выбор границы для определения аномальных заказов;
# - подсчёт статистической значимости различий в среднем количестве заказов на посетителя между группами по «сырым» данным, написание выводов и предположений;
# - подсчёт статистической значимости различий в среднем чеке заказа между группами по «сырым» данным, написание выводов и предположений;
# - подсчёт статистической значимости различий в среднем количестве заказов на посетителя между группами по «очищенным» данным, написание выводов и предположений;
# - подсчёт статистической значимости различий в среднем чеке заказа между группами по «очищенным» данным, написание выводов и предположений;
# - принятие и объяснение решения по результатам теста, варианты решений:
#    1. остановка теста, фиксация победы одной из групп;
#    2. остановка теста, фиксация отсутствия различий между группами;
#    3. продолжение теста.
#
# 4. Написание общих выводов по результатам исследования.

# %% [markdown]
# <div class="alert alert-success">
# <h2> Комментарий ревьюера <a class="tocSkip"> </h2>
#
# <b>Отлично!✅:</b> Здорово, что добавила описание и привела детальный план изучения проекта, так будет легче каждому соореентироваться в работе!
# </div>

# %% [markdown]
# ## Загрузка данных и подготовка их к анализу

# %% [markdown]
# ### Считывание файлов с данными о гипотезах, заказах и пользователях и сохранение в датафреймы

# %% [markdown]
# Импортируем необходимые библиотеки и модули.

# %%
import pandas as pd 
# импорт библиотеки pandas
from matplotlib import pyplot as plt 
# %matplotlib inline
# импорт модуля pyplot из библиотеки matplotlib
import numpy as np
# импорт библиотеки numpy
import scipy.stats as stats
# импорт модуля scipy.stats под псевдонимом stats
import datetime as dt
# импорт модуля datetime под псевдонимом dt

# %% [markdown]
# Считаем данные из файлов в датафреймы и сохраним в переменные `hypotheses`, `orders`, `visitors`.

# %%
try:
    hypotheses = pd.read_csv('/datasets/hypothesis.csv')
except:
    hypotheses = pd.read_csv('https://code.s3.yandex.net/datasets/hypothesis.csv')
#  чтение данных из csv-файла в датафрейм и сохранение в переменную ‘hypotheses’

try:
    orders = pd.read_csv('/datasets/orders.csv')
except:
    orders = pd.read_csv('https://code.s3.yandex.net/datasets/orders.csv')
#  чтение данных из csv-файла в датафрейм и сохранение в переменную ‘orders’

try:
    visitors = pd.read_csv('/datasets/visitors.csv')
except:
    visitors = pd.read_csv('https://code.s3.yandex.net/datasets/visitors.csv')
#  чтение данных из csv-файла в датафрейм и сохранение в переменную ‘visitors’

# %% [markdown]
# ### Вывод первых строк каждого набора данных

# %% [markdown]
# Выведем все строки датафрейма `hypotheses` на экран.

# %%
pd.set_option('display.max_colwidth', None)
# установка максимальной ширины столбцов
hypotheses
# отображение датафрейма ‘hypotheses’
# Out:
#                                                                                                      Hypothesis  \
# 0            Добавить два новых канала привлечения трафика, что позволит привлекать на 30% больше пользователей
# 1                                     Запустить собственную службу доставки, что сократит срок доставки заказов
# 2  Добавить блоки рекомендаций товаров на сайт интернет магазина, чтобы повысить конверсию и средний чек заказа
# 3           Изменить структура категорий, что увеличит конверсию, т.к. пользователи быстрее найдут нужный товар
# 4                              Изменить цвет фона главной страницы, чтобы увеличить вовлеченность пользователей
# 5                      Добавить страницу отзывов клиентов о магазине, что позволит увеличить количество заказов
# 6          Показать на главной странице баннеры с актуальными акциями и распродажами, чтобы увеличить конверсию
# ...

# %% [markdown]
# <div class="alert alert-success">
# <h2> Комментарий ревьюера <a class="tocSkip"> </h2>
#
# <b>Отлично!✅:</b> Данные загружены верно! Молодец, что применила настройку, так с гипотезами познакомились в полном объеме.
# </div>

# %% [markdown]
# Выведем первые 5 строк датафрейма `orders` на экран.

# %%
orders.head()
# отображение первых 5 строк датафрейма ‘orders’
# Out:
#    transactionId   visitorId        date  revenue group
# 0     3667963787  3312258926  2019-08-15     1650     B
# 1     2804400009  3642806036  2019-08-15      730     B
# 2     2961555356  4069496402  2019-08-15      400     A
# 3     3797467345  1196621759  2019-08-15     9759     B
# 4     2282983706  2322279887  2019-08-15     2308     B

# %% [markdown]
# Выведем первые 5 строк датафрейма `visitors` на экран.

# %%
visitors.head()
# отображение первых 5 строк датафрейма ‘visitors’
# Out:
#          date group  visitors
# 0  2019-08-01     A       719
# 1  2019-08-02     A       619
# 2  2019-08-03     A       507
# 3  2019-08-04     A       717
# 4  2019-08-05     A       756

# %% [markdown]
# ### Изучение общей информации о каждом датафрейме. Поиск пропусков и дубликатов

# %% [markdown]
# Выведем основную и статистическую информацию о датафреймах `hypotheses`, `orders` и `visitors`, число дубликатов, а также количество и долю пропущенных значений для всех столбцов.

# %%
def df_info(df, name):
# функция для вывода информации о датафрейме
    print('\033[1m', f'Таблица «{name}»', '\033[0m')
    # вывод названия датафрейма
    print(df.info())
    # вывод информации о структуре данных, хранящихся в переменной ‘df’
    print('-' * 65)
    # вывод символа «-» 65 раз
    print(df.describe())
    # вывод статистической информации о значениях столбцов датафрейма ‘df’
    print('-' * 65)
    # вывод символа «-» 65 раз
    print('\033[1m', f'Количество дубликатов в таблице «{name}»:', df.duplicated().sum(), '\033[0m')
    # вычисление количества дубликатов в датафрейме df’
    print('-' * 65)
    # вывод символа «-» 65 раз
    for i in df.columns:
        print('\033[1m', f'Столбец «{i}» -', 'количество NaN:', df[i].isna().sum(),
        ', процент NaN:', round(df[i].isna().mean() * 100, 2), '%', '\033[0m')
        # вычисление количества и доли отсутствующих значений (NaN) в каждом столбце датафрейма ‘df’
        print('-' * 65)
        # вывод символа «-» 65 раз
    
df_info(hypotheses, 'hypotheses')
# вызов функции df_info для датафрейма ‘hypotheses’
df_info(orders, 'orders')
# вызов функции df_info для датафрейма ‘orders’
df_info(visitors, 'visitors')
# вызов функции df_info для датафрейма ‘visitors’
# Out:
#  Таблица «hypotheses»
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9 entries, 0 to 8
# Data columns (total 5 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Hypothesis  9 non-null      object
#  1   Reach       9 non-null      int64
#  2   Impact      9 non-null      int64
#  3   Confidence  9 non-null      int64
#  4   Efforts     9 non-null      int64
# dtypes: int64(4), object(1)
# memory usage: 488.0+ bytes
# None
# -----------------------------------------------------------------
#            Reach     Impact  Confidence    Efforts
# count   9.000000   9.000000    9.000000   9.000000
# mean    4.777778   4.777778    5.555556   4.888889
# std     3.153481   3.192874    3.045944   2.803767
# min     1.000000   1.000000    1.000000   1.000000
# 25%     3.000000   3.000000    3.000000   3.000000
# 50%     3.000000   3.000000    7.000000   5.000000
# 75%     8.000000   7.000000    8.000000   6.000000
# ...

# %% [markdown]
# В таблице `hypotheses` 9 строк и 5 столбцов. Четыре столбца содержат целые числа (`'Reach'`, `'Impact'`, `'Confidence'`, `'Efforts'`) и один столбец — строки (`'Hypothesis'`). Дубликаты в таблице `hypotheses` отсутствуют. Пропущенные значения во всех колонках отсутствуют.
#
# В таблице `orders` 1 тыс. 197 строк и 5 столбцов. Три столбца содержат целые числа (`'transactionId'`, `'visitorId'`, `'revenue'`), два столбца — строки (`'date'`, `'group'`). Дубликаты в таблице `orders` отсутствуют. Пропущенные значения во всех колонках отсутствуют.
#
# В таблице `visitors` 62 строки и 3 столбца. Два столбца содержат строки (`'date'`, `'group'`), один столбец — целые числа (`'visitors'`). Дубликаты в таблице `visitors` отсутствуют. Пропущенные значения во всех колонках отсутствуют.

# %% [markdown]
# <div class="alert alert-success">
# <h2> Комментарий ревьюера <a class="tocSkip"> </h2>
#
# <b>Отлично!✅:</b> Это прекрасно!
# </div>

# %% [markdown]
# Выведем уникальные значения из столбцов с описаниями гипотез и группами A/B-теста, чтобы убедиться в отсутствии неявных дубликатов.

# %%
print('Уникальные гипотезы:', hypotheses['Hypothesis'].unique())
# получение уникальных значений из столбца ‘Hypothesis’ датафрейма ‘hypotheses’
print('Уникальные группы A/B-теста, в которые попали заказы:', orders['group'].unique())
# получение уникальных значений из столбца ‘group’ датафрейма ‘orders’
print('Уникальные группы A/B-теста, в которые попали пользователи:', visitors['group'].unique())
# получение уникальных значений из столбца ‘group’ датафрейма ‘visitors’
# Out:
# Уникальные гипотезы: ['Добавить два новых канала привлечения трафика, что позволит привлекать на 30% больше пользователей'
#  'Запустить собственную службу доставки, что сократит срок доставки заказов'
#  'Добавить блоки рекомендаций товаров на сайт интернет магазина, чтобы повысить конверсию и средний чек заказа'
#  'Изменить структура категорий, что увеличит конверсию, т.к. пользователи быстрее найдут нужный товар'
#  'Изменить цвет фона главной страницы, чтобы увеличить вовлеченность пользователей'
#  'Добавить страницу отзывов клиентов о магазине, что позволит увеличить количество заказов'
#  'Показать на главной странице баннеры с актуальными акциями и распродажами, чтобы увеличить конверсию'
#  'Добавить форму подписки на все основные страницы, чтобы собрать базу клиентов для email-рассылок'
#  'Запустить акцию, дающую скидку на товар в день рождения']
# Уникальные группы A/B-теста, в которые попали заказы: ['B' 'A']
# ...

# %% [markdown]
# Неявные дубликаты отсутствуют в столбцах с описаниями гипотез и группами A/B-теста.

# %% [markdown]
# Определим, есть ли дубликаты по отдельным столбцам датафреймов `orders` и `visitors`:
# - с идентификаторами заказов и идентификаторами пользователей, совершивших заказы;
# - с идентификаторами заказов и датами заказов;
# - с идентификаторами заказов и группами A/B-теста, в которые попали заказы;
# - с датами посещений интернет-магазина и группами A/B-теста, в которые попали посетители.

# %%
print('Количество дубликатов по столбцам «transactionId», «visitorId» датафрейма «orders»:', 
      orders.duplicated(['transactionId', 'visitorId']).sum())
# вычисление количества дубликатов по столбцам ‘transactionId’, ‘visitorId’ датафрейма ‘orders’
print('Количество дубликатов по столбцам «transactionId», «date» датафрейма «orders»:', 
      orders.duplicated(['transactionId', 'date']).sum())
# вычисление количества дубликатов по столбцам ‘transactionId’, ‘date’ датафрейма ‘orders’
print('Количество дубликатов по столбцам «transactionId», «group» датафрейма «orders»:', 
      orders.duplicated(['transactionId', 'group']).sum())
# вычисление количества дубликатов по столбцам ‘transactionId’, ‘group’ датафрейма ‘orders’
print('Количество дубликатов по столбцам «date», «group» датафрейма «visitors»:', 
      visitors.duplicated(['date', 'group']).sum())
# вычисление количества дубликатов по столбцам ‘date’, ‘group’ датафрейма ‘visitors’
# Out:
# Количество дубликатов по столбцам «transactionId», «visitorId» датафрейма «orders»: 0
# Количество дубликатов по столбцам «transactionId», «date» датафрейма «orders»: 0
# Количество дубликатов по столбцам «transactionId», «group» датафрейма «orders»: 0
# Количество дубликатов по столбцам «date», «group» датафрейма «visitors»: 0

# %% [markdown]
# Не существует неявных дубликатов по отдельным столбцам датафреймов `orders` и `visitors`.

# %% [markdown]
# <div class="alert alert-success">
# <h2> Комментарий ревьюера <a class="tocSkip"> </h2>
#
# <b>Отлично!✅:</b> Супер!
# </div>

# %% [markdown]
# Попавший в одну из групп посетитель должен оставаться в этой группе до конца теста. В противном случае будет неизвестно, что именно повлияло на его решения, и результаты A/B-теста нельзя будет интерпретировать однозначно.
#
# Проверим, есть ли пользователи, которые попали одновременно в обе группы A/B-теста. Вычислим количество таких пользователей, а также долю от общего числа посетителей интернет-магазина, участвовавших в A/B-тесте.

# %%
ab = []
# создание пустого списка ‘ab’
for i in orders.query('group == "B"')['visitorId'].values:
    if i in orders.query('group == "A"')['visitorId'].values:
        ab.append(i)
# проверка каждого элемента из группы B на наличие в группе A,
# если совпадение найдено, то этот элемент добавляется в список ‘ab’
unique_ab = np.unique(ab)
# запись в ‘unique_ab’ уникальных элементов из списка ‘ab’
print('Количество уникальных пользователей, которые попали в группу A и группу B:', len(unique_ab), 'человек')
# подсчёт количества элементов в ‘unique_ab’
print('Общее количество уникальных пользователей:', orders['visitorId'].nunique(), 'человек')
# получение количества уникальных значений в столбце ‘visitorId’ датафрейма ‘orders’
print('Доля пользователей, попавших в обе группы, от общего количества уникальных пользователей:', 
      round(len(unique_ab) / orders['visitorId'].nunique() * 100, 1), '%')
# деление количества элементов в ‘unique_ab’ на количество уникальных значений в столбце ‘visitorId’
# умножение полученного значения на 100 и округление результата до 1 знака после запятой
# вывод на экран доли в процентах
# Out:
# Количество уникальных пользователей, которые попали в группу A и группу B: 58 человек
# Общее количество уникальных пользователей: 1031 человек
# Доля пользователей, попавших в обе группы, от общего количества уникальных пользователей: 5.6 %

# %% [markdown]
# <div class="alert alert-info"> <b>Комментарий студента: </b>
#
# 58 пользователей оказались сразу и в группе A и в группе B, что составляет 5.6% от общего числа уникальных пользователей. <strike> Это небольшой процент, поэтому удалим таких пользователей. </strike> Это небольшой процент, желательно было бы отфильтровать таких пользователей, но в имеющихся данных количество посетителей в день агрегировано. Поэтому, пользователей, которые совершили покупки в обеих группах, можно удалить только из данных по заказам. Тем самым мы немного занизим количество покупок на посетителя. Оставим данные без изменений.
# </div>

# %%
# orders = orders.query('visitorId not in @unique_ab')
# фильтрация строк в датафрейме ‘orders’ с условием, что значения столбца ‘visitorId’ не входят в ‘unique_ab’
# print('Общее количество уникальных пользователей после исключения тех, кто попал в обе группы A/B-теста:', 
      # orders['visitorId'].nunique(), 'человека')
# получение количества уникальных значений в столбце ‘visitorId’ датафрейма ‘orders’

# %% [markdown]
# <strike> Посетители интернет-магазина, оказавшиеся в обеих группах A/B-теста, удалены из датафрейма `orders`. </strike>

# %% [markdown]
# <div class="alert alert-warning">
#     <h2> Комментарий ревьюера <a class="tocSkip"> </h2>
#
# <b>Можно лучше⚠️:</b> Конечно это не хорошо, и при проведении теста такое лучше избегать. Обычно, этих пользователей можно отфильтровать, но! в наших данных количество посетителей в день агрегировано. Поэтому, пользователей, которые совершили покупки в двух группах, мы можем удалить только из данных по покупкам. Тем самым мы немного занизим количество покупок на посетителя.
#
# Оптимально при работе с исходными данными отфильтровать пользователей, которые участвовали в двух группах из таблицы с визитами тоже. Но, поскольку мы этого сделать не можем, то продолжаем тест как есть, подсветив этот момент.
# </div>

# %% [markdown]
# <div class="alert alert-success">
# <h2> Комментарий ревьюера v2<a class="tocSkip"> </h2>
#
# <b>Отлично!✅:</b> Поправила, умница!
# </div>

# %% [markdown]
# ### Замена названий столбцов

# %% [markdown]
# Приведём к нижнему регистру названия столбцов датафрейма `hypotheses`.

# %%
hypotheses.columns = hypotheses.columns.str.lower()
# приведение названий столбцов датафрейма ‘hypotheses’ к нижнему регистру
hypotheses.columns 
# вывод списка столбцов датафрейма ‘hypotheses’
# Out:
# Index(['hypothesis', 'reach', 'impact', 'confidence', 'efforts'], dtype='object')

# %% [markdown]
# Приведём к «змеиному» регистру некоторые названия столбцов датафрейма `orders`.

# %%
orders.columns = orders.columns.str.replace('Id', '_id')
# приведение названий столбцов датафрейма ‘orders’, содержащих id, к змеиному регистру
orders.columns 
# вывод списка столбцов датафрейма ‘orders’
# Out:
# Index(['transaction_id', 'visitor_id', 'date', 'revenue', 'group'], dtype='object')

# %% [markdown]
# <div class="alert alert-success">
# <h2> Комментарий ревьюера <a class="tocSkip"> </h2>
#
# <b>Отлично!✅:</b> Хорошо, такой формат намного лучше!
# </div>

# %% [markdown]
# ### Изменение типа данных

# %% [markdown]
# Преобразуем строки в формат даты в столбцах, где указаны даты посещений интернет-магазина пользователями и даты заказов, чтобы иметь возможность выполнять операции с данными, связанными с датами.

# %%
orders['date'] = pd.to_datetime(orders['date'])
# преобразование значений столбца ‘date’ датафрейма ‘orders’ из строкового формата в формат даты
visitors['date'] = pd.to_datetime(visitors['date'])
# преобразование значений столбца ‘date’ датафрейма ‘visitors’ из строкового формата в формат даты

# %% [markdown]
# Выведем информацию о датафреймах после предобработки данных.

# %%
df_info(hypotheses, 'hypotheses')
# вызов функции df_info для датафрейма ‘hypotheses’
df_info(orders, 'orders')
# вызов функции df_info для датафрейма ‘orders’
df_info(visitors, 'visitors')
# вызов функции df_info для датафрейма ‘visitors’
# Out:
#  Таблица «hypotheses»
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9 entries, 0 to 8
# Data columns (total 5 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   hypothesis  9 non-null      object
#  1   reach       9 non-null      int64
#  2   impact      9 non-null      int64
#  3   confidence  9 non-null      int64
#  4   efforts     9 non-null      int64
# dtypes: int64(4), object(1)
# memory usage: 488.0+ bytes
# None
# -----------------------------------------------------------------
#            reach     impact  confidence    efforts
# count   9.000000   9.000000    9.000000   9.000000
# mean    4.777778   4.777778    5.555556   4.888889
# std     3.153481   3.192874    3.045944   2.803767
# min     1.000000   1.000000    1.000000   1.000000
# 25%     3.000000   3.000000    3.000000   3.000000
# 50%     3.000000   3.000000    7.000000   5.000000
# 75%     8.000000   7.000000    8.000000   6.000000
# ...

# %% [markdown]
# <div class="alert alert-info"> <b>Комментарий студента: </b>
#
# В результате предобработки данных в датафрейме `hypotheses` 9 строк и 5 столбцов. Четыре столбца содержат целые числа (`'Reach'`, `'Impact'`, `'Confidence'`, `'Efforts'`) и один столбец — строки (`'Hypothesis'`). Дубликаты в таблице `hypotheses` отсутствуют. Пропущенные значения во всех колонках отсутствуют.
#
# В датафрейме `orders` <strike> 1 тыс. 16 строк </strike> 1 тыс. 197 строк и 5 столбцов. Три столбца содержат целые числа (`'transactionId'`, `'visitorId'`, `'revenue'`), один столбец — даты (`'date'`), один столбец — строки (`'group'`). Дубликаты в таблице `orders` отсутствуют. Пропущенные значения во всех колонках отсутствуют.
#
# В датафрейме `visitors` 62 строки и 3 столбца. Один столбец содержит даты (`'date'`), один столбец — строки (`'group'`), один столбец — целые числа (`'visitors'`). Дубликаты в таблице `visitors` отсутствуют. Пропущенные значения во всех колонках отсутствуют.
#
# </div>

# %% [markdown]
# ### Вывод

# %% [markdown]
# <div class="alert alert-info"> <b>Комментарий студента: </b>
#
# Мы считали csv-файлы с данными о гипотезах по увеличению выручки интернет-магазина, посетителях и заказах, сохранили в датафреймы. Вывели первые строки каждого набора данных. Изучили общую информацию о датафреймах. Установили, что во всех датафреймах отсутствуют пропуски, а также явные дубликаты. Выяснили, что 58 уникальных пользователей попали одновременно в обе группы A/B-теста (A и B). <strike> Удалили их из датафрейма с заказами, чтобы результаты теста не были искажены. </strike> Привели к «змеиному» регистру названия столбцов датафреймов. Преобразовали значения столбцов датафреймов с датами из строкового формата в формат даты.
#
# </div>

# %% [markdown]
# <div class="alert alert-success">
# <h2> Комментарий ревьюера <a class="tocSkip"> </h2>
#
# <b>Отлично!✅:</b> Типы данных заменили, убедились в корректности данных, можем двигаться дальше!

# %% [markdown]
# ## Приоритизация гипотез

# %% [markdown]
# Приоритизируем сформулированные гипотезы по увеличению выручки интернет-магазина, чтобы максимизировать ожидаемое улучшение ключевых метрик бизнеса.

# %% [markdown]
# ### Приоритизация гипотез с применением фреймворка ICE

# %% [markdown]
# Применим фреймворк ICE (от англ. impact, confidence, efforts «влияние, уверенность, усилия») для приоритизации гипотез по увеличению выручки интернет-магазина, отсортируем их по убыванию приоритета.
#
# Фреймворк ICE состоит из трёх компонентов:
# - `impact` — насколько сильно изменение повлияет на пользователей, их опыт и удовлетворение от продукта;
# - `confidence` — насколько мы уверены, что это изменение повлияет на пользователей именно так;
# - `efforts` — сколько стоит протестировать эту гипотезу.
#
# Параметры фреймворка ICE оценены по шкале от 0 до 10.

# %%
hypotheses['ice'] = round(hypotheses['impact'] * hypotheses['confidence'] / hypotheses['efforts'], 1)
# подсчёт ICE для гипотез с округлением до 1-го знака после запятой
# добавление полученных значений ICE к таблице ‘hypotheses’
ice = hypotheses[['hypothesis', 'ice']].sort_values(by='ice', ascending=False)
# запись в переменную ‘ice’ столбцов ‘hypothesis’ и ‘ice’ датафрейма ‘hypotheses’, 
# отсортированных по убыванию значений столбца ‘ice’
ice.sort_values(by='ice').plot(x='hypothesis', y='ice', kind='barh', figsize=(15, 4), legend=False)
# построение барного графика для значений столбца ‘ice’
plt.title('Приоритизация гипотез с применением фреймворка ICE', fontsize=12)
# установка заголовка для графика
plt.xlabel('ICE', fontsize=10)
# установка подписи для горизонтальной оси графика
plt.ylabel('Гипотеза', fontsize=10)
# установка подписи для вертикальной оси графика
ice
# вывод таблицы ‘ice’, отсортированной по убыванию значений столбца ‘ice’
# Out:
#                                                                                                      hypothesis  \
# 8                                                       Запустить акцию, дающую скидку на товар в день рождения
# 0            Добавить два новых канала привлечения трафика, что позволит привлекать на 30% больше пользователей
# 7              Добавить форму подписки на все основные страницы, чтобы собрать базу клиентов для email-рассылок
# 6          Показать на главной странице баннеры с актуальными акциями и распродажами, чтобы увеличить конверсию
# 2  Добавить блоки рекомендаций товаров на сайт интернет магазина, чтобы повысить конверсию и средний чек заказа
# 1                                     Запустить собственную службу доставки, что сократит срок доставки заказов
# 5                      Добавить страницу отзывов клиентов о магазине, что позволит увеличить количество заказов
# ...

# %% [markdown]
# <div class="alert alert-success">
# <h2> Комментарий ревьюера <a class="tocSkip"> </h2>
#
# <b>Отлично!✅:</b> Диана, умничка, что округлила значения в колонке ice, большие цифры нам ни к чему!
# </div>

# %% [markdown]
# Наиболее перспективной по ICE (16.2) является 9-я гипотеза по увеличению выручки интернет-магазина «Запустить акцию, дающую скидку на товар в день рождения». Также к более приоритетным по ICE можно отнести 1-ю (13.3) и 8-ю (11.2) гипотезы: «Добавить два новых канала привлечения трафика, что позволит привлекать на 30% больше пользователей» и «Добавить форму подписки на все основные страницы, чтобы собрать базу клиентов для email-рассылок».
#
# Самая неперспективная гипотеза по ICE (1.0) — это 5-я гипотеза «Изменить цвет фона главной страницы, чтобы увеличить вовлеченность пользователей».
#
# Выведем список гипотез по увеличению выручки интернет-магазина вместе с ICE и его параметрами.

# %%
hypotheses[['hypothesis', 'impact', 'confidence', 'efforts', 'ice']].sort_values(by='ice', ascending=False)
# вывод столбцов ‘hypothesis’, ‘impact’, ‘confidence’, ‘efforts’ и ‘ice’, 
# отсортированных по убыванию значений столбца ‘ice’
# Out:
#                                                                                                      hypothesis  \
# 8                                                       Запустить акцию, дающую скидку на товар в день рождения
# 0            Добавить два новых канала привлечения трафика, что позволит привлекать на 30% больше пользователей
# 7              Добавить форму подписки на все основные страницы, чтобы собрать базу клиентов для email-рассылок
# 6          Показать на главной странице баннеры с актуальными акциями и распродажами, чтобы увеличить конверсию
# 2  Добавить блоки рекомендаций товаров на сайт интернет магазина, чтобы повысить конверсию и средний чек заказа
# 1                                     Запустить собственную службу доставки, что сократит срок доставки заказов
# 5                      Добавить страницу отзывов клиентов о магазине, что позволит увеличить количество заказов
# ...

# %% [markdown]
# Самая приоритетная гипотеза по ICE, связанная со скидкой на товар в день рождения, получила 9 баллов из 10 при оценке влияния на пользователей и уверенности в гипотезе. Это может быть связано с тем, что «приятная» для пользователей акция может удовлетворить их желание получить подарок и сэкономить деньги, что позволит интернет-магазину привлечь новых клиентов и стимулировать существующих покупать больше товаров. Акция со скидкой на товар в день рождения уже проверена временем и имеет положительные отзывы от клиентов других компаний, что снижает риск неудачи.
#
# Проверка гипотезы по увеличению выручки интернет-магазина «Запустить акцию, дающую скидку на товар в день рождения» является не очень затратной — параметр efforts оценён в 5 баллов из 10. Запуск акции не требует много времени и ресурсов, не влияет на остальные аспекты бизнеса, такие как ассортимент товаров или ценообразование, что позволяет сосредоточиться на одной задаче без влияния на другие области. Для реализации идеи можно отправлять электронные письма или SMS-сообщения с информацией об акции и поздравлением с днём рождения, показывать баннер с информацией об акции на сайте интернет-магазина, публиковать посты с поздравлениями и информацией об акции в аккаунтах магазина в социальных сетях.

# %% [markdown]
# <div class="alert alert-success">
# <h2> Комментарий ревьюера <a class="tocSkip"> </h2>
#
# <b>Отлично!✅:</b> Принято!
# </div>

# %% [markdown]
# ### Приоритизация гипотез с применением фреймворка RICE

# %% [markdown]
# Теперь используем фреймворк RICE (R от англ. reach, «охват») для приоритизации гипотез по увеличению выручки интернет-магазина.
#
# Фреймворк RICE состоит из четырёх компонентов:
# - `reach` — скольких пользователей затронет изменение, которое мы хотим внести;
# - `impact` — насколько сильно изменение повлияет на пользователей, их опыт и удовлетворение от продукта;
# - `confidence` — насколько мы уверены, что это изменение повлияет на пользователей именно так;
# - `efforts` — сколько стоит протестировать эту гипотезу.
#
# Как и в случае ICE, параметры фреймворка RICE оценены по шкале от 0 до 10.

# %%
hypotheses['rice'] = hypotheses['reach'] * hypotheses['impact'] * hypotheses['confidence'] / hypotheses['efforts']
# подсчёт RICE для гипотез
# добавление полученных значений RICE к таблице ‘hypotheses’
rice = hypotheses[['hypothesis', 'rice']].sort_values(by='rice', ascending=False)
# запись в переменную ‘rice’ столбцов ‘hypothesis’ и ‘rice’ датафрейма ‘hypotheses’, 
# отсортированных по убыванию значений столбца ‘rice’
rice.sort_values(by='rice').plot(x='hypothesis', y='rice', kind='barh', figsize=(15, 4), legend=False)
# построение барного графика для значений столбца ‘rice’
plt.title('Приоритизация гипотез с применением фреймворка RICE', fontsize=12)
# установка заголовка для графика
plt.xlabel('RICE', fontsize=10)
# установка подписи для горизонтальной оси графика
plt.ylabel('Гипотеза', fontsize=10)
# установка подписи для вертикальной оси графика
rice
# вывод таблицы ‘rice’, отсортированной по убыванию значений столбца ‘rice’
# Out:
#                                                                                                      hypothesis  \
# 7              Добавить форму подписки на все основные страницы, чтобы собрать базу клиентов для email-рассылок
# 2  Добавить блоки рекомендаций товаров на сайт интернет магазина, чтобы повысить конверсию и средний чек заказа
# 0            Добавить два новых канала привлечения трафика, что позволит привлекать на 30% больше пользователей
# 6          Показать на главной странице баннеры с актуальными акциями и распродажами, чтобы увеличить конверсию
# 8                                                       Запустить акцию, дающую скидку на товар в день рождения
# 3           Изменить структура категорий, что увеличит конверсию, т.к. пользователи быстрее найдут нужный товар
# 1                                     Запустить собственную службу доставки, что сократит срок доставки заказов
# ...

# %% [markdown]
# Добавление параметра, связанного с охватом пользователей, привело к изменению приоритетов гипотез по увеличению выручки интернет-магазина.
#
# По RICE самая перспективная гипотеза (RICE равен 112) — это 8-я гипотеза «Добавить форму подписки на все основные страницы, чтобы собрать базу клиентов для email-рассылок». В 2 раза меньше RICE (равен 56) у 3-й гипотезы «Добавить блоки рекомендаций товаров на сайт интернет магазина, чтобы повысить конверсию и средний чек заказа». Третье место по приоритету (RICE равен 40) занимают две гипотезы — 1-я «Добавить два новых канала привлечения трафика, что позволит привлекать на 30% больше пользователей» и 7-я «Показать на главной странице баннеры с актуальными акциями и распродажами, чтобы увеличить конверсию».
#
# Лишь 16.2 составляет RICE у 9-й гипотезы «Запустить акцию, дающую скидку на товар в день рождения», что совпадает со значением ICE (равен 16.2). Это можно объяснить тем, что данная гипотеза затрагивает очень мало пользователей. Наименее перспективной по RICE (равен 3), как и по ICE (равен 1), является 5-я гипотеза «Изменить цвет фона главной страницы, чтобы увеличить вовлеченность пользователей».

# %% [markdown]
# Выведем список гипотез по увеличению выручки интернет-магазина вместе с ICE, RICE и их параметрами.

# %%
hypotheses.sort_values(by='rice', ascending=False)
# вывод столбцов датафрейма ‘hypotheses’, 
# отсортированных по убыванию значений столбца ‘rice’
# Out:
#                                                                                                      hypothesis  \
# 7              Добавить форму подписки на все основные страницы, чтобы собрать базу клиентов для email-рассылок
# 2  Добавить блоки рекомендаций товаров на сайт интернет магазина, чтобы повысить конверсию и средний чек заказа
# 0            Добавить два новых канала привлечения трафика, что позволит привлекать на 30% больше пользователей
# 6          Показать на главной странице баннеры с актуальными акциями и распродажами, чтобы увеличить конверсию
# 8                                                       Запустить акцию, дающую скидку на товар в день рождения
# 3           Изменить структура категорий, что увеличит конверсию, т.к. пользователи быстрее найдут нужный товар
# 1                                     Запустить собственную службу доставки, что сократит срок доставки заказов
# ...

# %% [markdown]
# У наиболее приоритетной по RICE и входящей в топ-3 по приоритету по ICE гипотезы «Добавить форму подписки на все основные страницы, чтобы собрать базу клиентов для email-рассылок» охват пользователей оценён в 10 баллов из 10, влияние на пользователей — в 7 баллов, уверенность в гипотезе — в 8 баллов, затраты ресурсов на проверку гипотезы — в 5 баллов. Форма подписки может быть размещена на всех основных страницах сайта, что обеспечит максимальный охват пользователей. Могут быть получены целевые подписчики, заинтересованные в продуктах интернет-магазина. Они могут стать частью сообщества, что укрепит связь с брендом и увеличит лояльность. Рассылка новостей, статей и специальных предложений поможет поддерживать интерес аудитории и стимулировать её к совершению покупок.
#
# У гипотезы «Запустить акцию, дающую скидку на товар в день рождения» параметр reach равен 1, поэтому он не оказал влияния на RICE. Причиной низкого охвата пользователей может являться то, что среди посетителей магазина мало тех, кто является именинником при покупке товаров, так как день рождения бывает только один раз в году. Некоторые пользователи могут не успеть или не захотеть воспользоваться скидкой в день рождения.

# %% [markdown]
# <div class="alert alert-success">
# <h2> Комментарий ревьюера <a class="tocSkip"> </h2>
#
# <b>Отлично!✅:</b> Отлично, что вывела таблицу дважды и применила сортировку по одному из фреймворков - так мы более наглядно можем наблюдать различия в их работе!
# </div>

# %% [markdown]
# ### Вывод

# %% [markdown]
# Мы применили фреймворки ICE и RICE для приоритизации гипотез по увеличению выручки интернет-магазина. Приоритизация гипотез при использовании ICE и RICE различается. При расчёте RICE, в отличие от ICE, мы принимали во внимание количество пользователей, которых затронет изменение, которое мы хотим внести.
#
# Без учёта охвата пользователей самой перспективной является гипотеза по увеличению выручки интернет-магазина, связанная с запуском акции, дающей скидку на товар в день рождения, а с учётом охвата пользователей — гипотеза, связанная с добавлением формы подписки на все основные страницы, чтобы собрать базу клиентов для email-рассылок.

# %% [markdown]
# <div class="alert alert-success">
# <h2> Комментарий ревьюера <a class="tocSkip"> </h2>
#
# <b>Отлично!✅:</b> Совершенно верно!
# </div>

# %% [markdown]
# ## Анализ A/B-теста

# %% [markdown]
# Мы провели A/B-тест и получили результаты для проведения анализа.
#
# Определим количество и долю уникальных пользователей в группе A и в группе B.

# %%
print('Общее количество уникальных пользователей:', orders['visitor_id'].nunique(), 'человек')
# подсчёт количества уникальных значений в столбце ‘visitor_id’ датафрейма ‘orders’

print('Количество уникальных пользователей только в группе A:', 
      (orders.query('group == "A"')['visitor_id'].nunique()) - len(unique_ab), 'человек')
# подсчёт количества уникальных значений в столбце ‘visitor_id’ датафрейма ‘orders’ 
# для группы со значением ‘А’ в столбце ‘group’
# вычет количества уникальных пользователей, попавших в обе группы

print('Количество уникальных пользователей только в группе B:', 
      (orders.query('group == "B"')['visitor_id'].nunique()) - len(unique_ab), 'человек')
# подсчёт количества уникальных значений в столбце ‘visitor_id’ датафрейма ‘orders’ 
# для группы со значением ‘B’ в столбце ‘group’
# вычет количества уникальных пользователей, попавших в обе группы

print('Количество уникальных пользователей, которые попали в группу A и группу B:', len(unique_ab), 'человек')
# подсчёт количества элементов в ‘unique_ab’

print('Доля пользователей, оказавшихся только в группе A:', 
round(((orders.query('group == "A"')['visitor_id'].nunique()) - len(unique_ab)) / orders['visitor_id'].nunique() * 100, 1),
      '%')
# деление количества уникальных пользователей в группе A на общее количество уникальных пользователей
# умножение полученного значения на 100 и округление результата до 1 знака после запятой
# вывод на экран доли в процентах

print('Доля пользователей, оказавшихся только в группе B:', 
round(((orders.query('group == "B"')['visitor_id'].nunique()) - len(unique_ab)) / orders['visitor_id'].nunique() * 100, 1), 
      '%')
# деление количества уникальных пользователей в группе B на общее количество уникальных пользователей
# умножение полученного значения на 100 и округление результата до 1 знака после запятой
# вывод на экран доли в процентах

print('Доля пользователей, попавших в обе группы, от общего количества уникальных пользователей:', 
      round(len(unique_ab) / orders['visitor_id'].nunique() * 100, 1), '%')
# деление количества элементов в ‘unique_ab’ на количество уникальных значений в столбце ‘visitorId’
# умножение полученного значения на 100 и округление результата до 1 знака после запятой
# вывод на экран доли в процентах
# Out:
# Общее количество уникальных пользователей: 1031 человек
# Количество уникальных пользователей только в группе A: 445 человек
# Количество уникальных пользователей только в группе B: 528 человек
# Количество уникальных пользователей, которые попали в группу A и группу B: 58 человек
# Доля пользователей, оказавшихся только в группе A: 43.2 %
# Доля пользователей, оказавшихся только в группе B: 51.2 %
# Доля пользователей, попавших в обе группы, от общего количества уникальных пользователей: 5.6 %

# %% [markdown]
# <div class="alert alert-info"> <b>Комментарий студента: </b>
#
# Пользователи распределены по группам A/B-теста относительно равномерно. В группу A попало 445 посетителей интернет-магазина, что составляет <strike> 46% </strike> 43.2% от общего количества посетителей. В группе B оказалось больше пользователей — 528, что составляет <strike> 54% </strike> 51.2% от общего числа пользователей. Как уже было отмечено ранее, в группах A и B одновременно оказалось 58 человек — 5.6% от всех участников A/B-теста.
#
# </div>

# %% [markdown]
# <div class="alert alert-success">
# <h2> Комментарий ревьюера <a class="tocSkip"> </h2>
#
# <b>Отлично!✅:</b> Можем сказать, что группа В более эффективно работает!
# </div>

# %% [markdown]
# Соберём агрегированные кумулятивные по дням данные о заказах и посетителях интернет-магазина. Объявим датафрейм `cumulative_data` со столбцами:
#
# - `date` — дата
#
# - `group` — группа A/B-теста (A или B)
#
# - `orders` — кумулятивное количество заказов на указанную дату в указанной группе
#
# - `buyers` — кумулятивное количество пользователей, совершивших хотя бы один заказ, на указанную дату в указанной группе
#
# - `revenue` — кумулятивная выручка на указанную дату в указанной группе
#
# - `visitors` — кумулятивное количество посетителей интернет-магазина на указанную дату в определённой группе

# %%
dates_groups = orders[['date', 'group']].drop_duplicates()
# создание массива уникальных пар значений дат и групп A/B-теста

orders_aggregated = dates_groups.apply(
    lambda x: orders[np.logical_and(
        orders['date'] <= x['date'], orders['group'] == x['group'])].agg(
        {'date' : 'max', 'group' : 'max', 'transaction_id' : 'nunique', 'visitor_id' : 'nunique', 'revenue' : 'sum'}), 
    axis=1).sort_values(by=['date', 'group'])
# получение строк таблицы ‘orders’, дата которых меньше или равна дате элемента из ‘dates_groups’, 
# а группа теста равна группе из ‘dates_groups’
# вычисление максимальной даты
# рассчёт максимума для группы, чтобы столбец ‘group’ не пропал из итогового вывода
# вычисление числа уникальных ID заказов и пользователей
# подсчёт суммы средних чеков
# применение методов к каждой строке датафрейма
# сортировка результатов по столбцам ‘date’ и ‘group’
# получение агрегированных кумулятивных по дням данных о заказах
 
visitors_aggregated = dates_groups.apply(
    lambda x: visitors[np.logical_and(
        visitors['date'] <= x['date'], visitors['group'] == x['group'])].agg(
        {'date' : 'max', 'group' : 'max', 'visitors' : 'sum'}), axis=1).sort_values(by=['date', 'group'])
# получение строк таблицы ‘visitors’, дата которых меньше или равна дате элемента из ‘dates_groups’, 
# а группа теста равна группе из ‘dates_groups’
# вычисление максимальной даты
# рассчёт максимума для группы, чтобы столбец ‘group’ не пропал из итогового вывода
# подсчёт суммарного количества пользователей
# применение методов к каждой строке датафрейма
# сортировка результатов по столбцам ‘date’ и ‘group’
# получение агрегированных кумулятивных по дням данных о посетителях интернет-магазина

cumulative_data = orders_aggregated.merge(visitors_aggregated, left_on=['date', 'group'], right_on=['date', 'group'])
# объединение кумулятивных данных в одной таблице ‘cumulative_data’
cumulative_data.columns = ['date', 'group', 'orders', 'buyers', 'revenue', 'visitors']
# присваивание названий столбцам таблицы ‘cumulative_data’

cumulative_data
# вывод таблицы ‘cumulative_data’ на экран
# Out:
#          date group  orders  buyers  revenue  visitors
# 0  2019-08-01     A      24      20   148579       719
# 1  2019-08-01     B      21      20   101217       713
# 2  2019-08-02     A      44      38   242401      1338
# 3  2019-08-02     B      45      43   266748      1294
# 4  2019-08-03     A      68      62   354874      1845
# ..        ...   ...     ...     ...      ...       ...
# 57 2019-08-29     B     596     544  5559398     17708
# 58 2019-08-30     A     545     493  4022970     18037
# 59 2019-08-30     B     620     567  5774631     18198
# 60 2019-08-31     A     557     503  4084803     18736
# 61 2019-08-31     B     640     586  5907760     18916
#
# [62 rows x 6 columns]

# %% [markdown]
# Пользователи, принявшие участие в A/B-тесте, посещали интернет-магазин с 1 по 31 августа 2019 года. Соответственно, длительность эксперимента составила 1 месяц.

# %% [markdown]
# <div class="alert alert-success">
# <h2> Комментарий ревьюера <a class="tocSkip"> </h2>
#
# <b>Отлично!✅:</b> Диана, здорово, что так детально проанализировала данные. Очень развернуто получилось, лишних вопросов не возникает:)
# </div>

# %% [markdown]
# ### Анализ графиков кумулятивной выручки и кумулятивного среднего чека по группам, относительного изменения кумулятивного среднего чека группы B к группе A

# %% [markdown]
# Построим график кумулятивной выручки по дням и группам A/B-тестирования.

# %%
cumulative_revenue_a = cumulative_data[cumulative_data['group'] == 'A'][['date', 'revenue', 'orders']]
# создание датафрейма с кумулятивным количеством заказов и кумулятивной выручкой по дням в группе А

cumulative_revenue_b = cumulative_data[cumulative_data['group'] == 'B'][['date', 'revenue', 'orders']]
# создание датафрейма с кумулятивным количеством заказов и кумулятивной выручкой по дням в группе B

plt.figure(figsize=(18, 4))
# установка размера графика

plt.plot(cumulative_revenue_a['date'], cumulative_revenue_a['revenue'], label='A')
# построение графика выручки группы А

plt.plot(cumulative_revenue_b['date'], cumulative_revenue_b['revenue'], label='B')
# построение графика выручки группы B

plt.title('Кумулятивная выручка по дням и группам A/B-теста', fontsize=12)
# установка заголовка для графика

plt.xlabel('Дата', fontsize=10)
# установка подписи для горизонтальной оси графика

plt.ylabel('Кумулятивная выручка', fontsize=10)
# установка подписи для вертикальной оси графика

plt.legend();
# отображение легенды на графике

# %% [markdown]
# <div class="alert alert-info"> <b>Комментарий студента: </b>
#
# Для обеих групп характерно увеличение выручки в течение всего теста.
#
# 1 августа более высокая выручка была у группы A. <strike> 5 августа </strike> Уже 2 августа группа B вырвалась вперёд и продолжала лидировать до конца теста.
#
# На графике группы A увеличение выручки происходило равномерно.
#
# На графике группы B с 18 по 19 августа произошёл резкий рост кумулятивной выручки с <strike> 2 млн. 190 тыс. </strike> 2 млн. 686 тыс. до <strike> 3 млн. 620 тыс. </strike> 4 млн. 116 тыс. Это может сигнализировать о всплесках числа заказов, а также о появлении очень дорогих заказов в выборке.
#
# В последний день эксперимента кумулятивная выручка группы A составила <strike> 3 млн. 364 тыс. </strike> 4 млн. 84 тыс., тогда как кумулятивная выручка группы B — <strike> 5 млн. 68 тыс. </strike> 5 млн. 907 тыс.
#
# </div>

# %% [markdown]
# <div class="alert alert-success">
# <h2> Комментарий ревьюера <a class="tocSkip"> </h2>
#
# <b>Отлично!✅:</b> Согласна, все может быть!
# </div>

# %% [markdown]
# Построим график кумулятивного среднего чека по дням и группам A/B-тестирования.

# %%
plt.figure(figsize=(18, 4))
# установка размера графика

plt.plot(cumulative_revenue_a['date'], cumulative_revenue_a['revenue'] / cumulative_revenue_a['orders'], label='A')
# деление кумулятивной выручки группы А на кумулятивное число заказов группы А
# построение графика среднего чека группы А

plt.plot(cumulative_revenue_b['date'], cumulative_revenue_b['revenue'] / cumulative_revenue_b['orders'], label='B')
# деление кумулятивной выручки группы B на кумулятивное число заказов группы B
# построение графика среднего чека группы B

plt.title('Кумулятивный средний чек по дням и группам A/B-теста', fontsize=12)
# установка заголовка для графика

plt.xlabel('Дата', fontsize=10)
# установка подписи для горизонтальной оси графика

plt.ylabel('Кумулятивный средний чек', fontsize=10)
# установка подписи для вертикальной оси графика

plt.legend();
# отображение легенды на графике

# %% [markdown]
# <div class="alert alert-info"> <b>Комментарий студента: </b>
#
# У группы A с 1 по 6 августа происходило снижение среднего чека, затем повышение до 14 августа, далее средний чек стал относительно стабильным. Можно отметить небольшой рост среднего чека ближе к концу теста.
#
# У группы B кумулятивное значение среднего чека колебалось с 1 по 18 августа в пределах 5-7 тыс. 19 августа средний чек, как и выручка, резко увеличился до <strike> 10.4 тыс. </strike> 10 тыс. 214. Резкий всплеск на графике группы B может быть связан с попаданием в выборку крупных заказов. После этого, до конца теста происходило постепенное снижение среднего чека. При этом значение среднего чека у группы B после резкого скачка оставалось до конца теста более высоким, чем у группы A, и на крайнюю дату составило <strike> 9 тыс. 250 </strike> 9 тыс. 230 (на <strike> 2 тыс. 61 </strike> 1 тыс. 897 больше среднего чека группы A).
#
# </div>

# %% [markdown]
# <div class="alert alert-success">
# <h2> Комментарий ревьюера <a class="tocSkip"> </h2>
#
# <b>Отлично!✅:</b> Молодец, верно, группа В нестабильна. Возможно, в данную группу в середине теста попали крупные заказы. Необходимо будет учесть этот факт при принятии решения о результатах A/B-теста:)
# </div>

# %% [markdown]
# Построим график относительного изменения кумулятивного среднего чека группы B к группе A.

# %%
merged_cumulative_revenue = cumulative_revenue_a.merge(
    cumulative_revenue_b, left_on='date', right_on='date', how='left', suffixes=['_a', '_b'])
# сбор данных в одном датафрейме ‘merged_cumulative_revenue’
# объединение таблицы ‘cumulative_revenue_a’ и ‘cumulative_revenue_b’  так, 
# чтобы она содержала столбцы ‘date’, ‘revenueA’, ‘ordersA’, ‘revenueB’, ‘ordersB’

plt.figure(figsize=(18, 4))
# установка размера графика

plt.plot(merged_cumulative_revenue['date'], 
         (merged_cumulative_revenue['revenue_b'] / merged_cumulative_revenue['orders_b']) / (
             merged_cumulative_revenue['revenue_a'] / merged_cumulative_revenue['orders_a']) - 1)
# построение графика относительного различия кумулятивного среднего чека группы B к группе A

plt.title('Относительное изменение кумулятивного среднего чека группы B к группе A по дням', fontsize=12)
# установка заголовка для графика

plt.xlabel('Дата', fontsize=10)
# установка подписи для горизонтальной оси графика

plt.ylabel('Отношение кумулятивных средних чеков', fontsize=9)
# установка подписи для вертикальной оси графика

plt.axhline(y=0, color='black', linestyle='--');
# добавление горизонтальной оси

# %% [markdown]
# <div class="alert alert-info"> <b>Комментарий студента: </b>
#
# <strike> В первые дни </strike> В первый день эксперимента отношение среднего чека группы B к среднему чеку группы A было отрицательным, что указывает на то, что начале теста пользователи из группы B оставляли меньшее количество денег при совершении покупок в интернет-магазине, чем пользователи из группы A. Также <strike> с 11 по 17 августа </strike> с 12 по 15 августа относительное изменение кумулятивного среднего чека группы B к группе A было отрицательным. В остальные дни теста изменение было положительным.
#
# На графике можно наблюдать резкие скачки, что может свидетельствовать о совершении аномальных заказов. С 19 августа график стал более стабильным, и средний чек группы B до конца теста был выше, чем средний чек группы A, хотя разница между ними постепенно уменьшалась <strike> с 0.52 до 0.29 </strike> с 0.49 до 0.26.
#
# </div>

# %% [markdown]
# <div class="alert alert-success">
# <h2> Комментарий ревьюера <a class="tocSkip"> </h2>
#
# <b>Отлично!✅:</b> Отлично!
# </div>

# %% [markdown]
# ### Анализ графика кумулятивного среднего количества заказов на пользователя по группам и относительного изменения кумулятивного среднего количества заказов на пользователя группы B к группе A

# %% [markdown]
# Построим график кумулятивного среднего количества заказов на посетителя по группам.

# %%
cumulative_data['conversion'] = cumulative_data['orders'] / cumulative_data['visitors']
# рассчёт среднего количества заказов на посетителя
# добавление в таблицу ‘cumulative_data’ столбца ‘conversion’ 
# c отношением числа заказов к количеству пользователей в указанной группе в указанный день

cumulative_data_a = cumulative_data[cumulative_data['group'] == 'A']
# сохранение в переменной cumulative_data_a данных о заказах в группе A

cumulative_data_b = cumulative_data[cumulative_data['group'] == 'B'] 
# сохранение в переменной cumulative_data_b данных о заказах в группе B

plt.figure(figsize=(18, 4))
# установка размера графика

plt.plot(cumulative_data_a['date'], cumulative_data_a['conversion'], label='A')
# построение графика кумулятивного среднего количества заказов на посетителя по группе A

plt.plot(cumulative_data_b['date'], cumulative_data_b['conversion'], label='B')
# построение графика кумулятивного среднего количества заказов на посетителя по группе B

plt.legend()
# отображение легенды на графике

plt.title('Кумулятивное среднее количество заказов на посетителя по группам и по дням', fontsize=12)
# установка заголовка для графика

plt.xlabel('Дата', fontsize=10)
# установка подписи для горизонтальной оси графика

plt.ylabel('Кумулятивное среднее кол-во заказов', fontsize=10)
# установка подписи для вертикальной оси графика

plt.axis([dt.datetime(2019, 8, 1), dt.datetime(2019, 8, 31), 0, 0.05]);
# установка масштаба осей
# передача минимального и максимального значения горизонтальной и вертикальной оси

# %% [markdown]
# <div class="alert alert-info"> <b>Комментарий студента: </b>
#
# В начале теста группа A имела большее кумулятивное среднее количество заказов на посетителя, но вскоре группа B выровнялась и зафиксировалась примерно около одного значения <strike> (0.03) </strike> (0.033-0.035), больше значения группы A <strike> (0.025) </strike> (0.029-0.03).
#
# </div>

# %% [markdown]
# <div class="alert alert-success">
# <h2> Комментарий ревьюера <a class="tocSkip"> </h2>
#
# <b>Отлично!✅:</b> Умница, правильно!
# </div>

# %% [markdown]
# Построим график относительного изменения кумулятивного среднего количества заказов на посетителя группы B к группе A.

# %%
merged_cumulative_conversions = cumulative_data_a[['date', 'conversion']].merge(
    cumulative_data_b[['date', 'conversion']], left_on='date', right_on='date', how='left', suffixes=['_a', '_b'])
# объединение таблицы ‘cumulative_data_a’ и ‘cumulative_data_b’ так, 
# чтобы она содержала столбцы ‘date’, ‘conversion_a’, ‘conversion_b’
# сохранение результатов в переменной ‘merged_cumulative_conversions’

plt.figure(figsize=(18, 4))
# установка размера графика

plt.plot(merged_cumulative_conversions['date'], 
         merged_cumulative_conversions['conversion_b'] / merged_cumulative_conversions['conversion_a'] - 1)
# построение графика относительного изменения кумулятивного среднего количества заказов на посетителя группы B к группе A

plt.title('Относительное изменение кумулятивного среднего количества заказов на посетителя группы B к группе A по дням', 
          fontsize=12)
# установка заголовка для графика

plt.xlabel('Дата', fontsize=10)
# установка подписи для горизонтальной оси графика

plt.ylabel('Различие метрики между группами', fontsize=10)
# установка подписи для вертикальной оси графика

plt.axhline(y=0, color='black', linestyle='--')
# добавление пунктирной линии оси X чёрного цвета со значением оси Y = 0

plt.axhline(y=0.15, color='grey', linestyle='--')
# добавление пунктирной линии оси X серого цвета со значением оси Y = 0.15

plt.axis([dt.datetime(2019, 8, 1), dt.datetime(2019, 8, 31), -0.3, 0.3]);
# установка масштаба осей

# %% [markdown]
# <div class="alert alert-info"> <b>Комментарий студента: </b>
#
# Почти с самого начала теста группа B лидирует по кумулятивному среднему количеству заказов на посетителя. К концу эксперимента группа B зафиксировалась около прироста в <strike> 14-16% </strike> 13.8% относительно группы A.
#
# </div>

# %% [markdown]
# <div class="alert alert-success">
# <h2> Комментарий ревьюера <a class="tocSkip"> </h2>
#
# <b>Отлично!✅:</b>  Хорошо, давай посмотрим на аномалии:)
# </div>

# %% [markdown]
# ### Анализ выбросов в данных

# %% [markdown]
# Пользователи, совершившие много заказов, влияют на конверсию. Скорее всего, их поведение отличается от нормального. Если речь не идёт об интернет-магазине с регулярным спросом, «обычный» пользователь совершает не больше двух заказов за короткий срок. Подсчитаем количество заказов по пользователям.

# %%
orders_by_visitors = (orders.groupby('visitor_id', as_index=False).agg({'transaction_id': 'nunique'}))
# группировка данных по столбцу ‘visitor_id’
# подсчёт уникальных значений столбца ‘transaction_id’ по сгрупированным данным
# сохранение результата в переменной ‘orders_by_visitors’

orders_by_visitors.columns = ['visitor_id', 'orders']
# присваивание названий столбцам таблицы ‘orders_by_visitors’

orders_by_visitors.sort_values(by='orders', ascending=False).head(15)
# сортировка значений датафрейма ‘orders_by_visitors’ по убыванию количества заказов пользователей
# вывод на экран первых 15-ти строк
# Out:
#       visitor_id  orders
# 1023  4256040402      11
# 591   2458001652      11
# 569   2378935119       9
# 487   2038680547       8
# 44     199603092       5
# 744   3062433592       5
# 55     237748145       5
# 917   3803269165       5
# 299   1230306981       5
# 897   3717692402       5
# 393   1614305549       4
# 114    457167155       4
# 619   2587333274       4
# 340   1404934699       3
# 937   3908431265       3

# %% [markdown]
# <div class="alert alert-info"> <b>Комментарий студента: </b>
#
# Есть пользователи, которые совершали <strike> 2 и 3 заказа </strike> 3-5, 8, 9 и 11 заказов.
#
# Определим, сколько пользователей оформляли то или иное число заказов. Построим точечный график количества заказов по пользователям.
#
# </div>

# %%
x_values = pd.Series(range(0, len(orders_by_visitors)))
# серия из чисел от 0 до количества наблюдений в ‘orders_by_visitors’

plt.figure(figsize=(18, 4))
# установка размера графика

plt.scatter(x_values, orders_by_visitors['orders'])
# построение точечной диаграммы числа заказов на одного пользователя
# передача значений переменной ‘x_values’ для горизонтальной оси
# передача значений столбца ‘orders’ датафрейма ‘orders_by_visitors’ для вертикальной оси

plt.title('Распределение количества заказов по пользователям', 
          fontsize=12)
# установка заголовка для графика

plt.xlabel('Количество пользователей', fontsize=10)
# установка подписи для горизонтальной оси графика

plt.ylabel('Количество заказов', fontsize=10)
# установка подписи для вертикальной оси графика

orders_by_visitors.groupby('orders').agg({'visitor_id': 'count'})
# группировка данных по столбцу ‘orders’ и подсчёт количества уникальных значений ‘visitor_id’ в каждой группе
# Out:
#         visitor_id
# orders
# 1              937
# 2               64
# 3               17
# 4                3
# 5                6
# 8                1
# 9                1
# 11               2

# %% [markdown]
# <div class="alert alert-info"> <b>Комментарий студента: </b>
#
# Большая часть посетителей интернет-магазина совершала один заказ (937 человек). Намного меньше пользователей с 2-мя заказами (64 человека). <strike> Совсем мало заказавших 3 раза (7 человек из 973). </strike> Ещё меньше заказавших 3 раза и более (30 человек). <strike> Их можно считать аномальными. </strike> Выясним, <strike> 2 заказа — это нормально или много, </strike> какое число заказов является нормальным, а какое аномальным, посчитав выборочные перцентили количества заказов на одного пользователя.
#
# Посчитаем 95-й и 99-й перцентили количества заказов на пользователя. Выберем границу для определения аномальных пользователей.
#
# </div>

# %% [markdown]
# <div class="alert alert-success">
# <h2> Комментарий ревьюера <a class="tocSkip"> </h2>
#
# <b>Отлично!✅:</b> Верно!
# </div>

# %%
print(np.percentile(orders_by_visitors['orders'], [95, 99]))
# вычисление 95-го и 99-го процентилей списка значений столбца ‘orders’ датафрейма ‘orders_by_visitors’
# Out:
# [2. 4.]

# %% [markdown]
# <div class="alert alert-info"> <b>Комментарий студента: </b>
#
# Не более 5% пользователей совершали больше <strike> одного заказа </strike> двух заказов. И не более 1% пользователей — больше <strike> двух </strike> четырёх заказов.
#
# Выберем 2 заказа на одного пользователя за верхнюю границу числа заказов.
#
# Вычислим количество заказов по пользователям, которые попали сразу в обе группы A/B-теста.
#
# </div>

# %% [markdown]
# <div class="alert alert-success">
# <h2> Комментарий ревьюера <a class="tocSkip"> </h2>
#
# <b>Отлично!✅:</b> Отлично, идем дальше!
# </div>

# %%
# try:
    # orders_original = pd.read_csv('/datasets/orders.csv')
# except:
    # orders_original = pd.read_csv('https://code.s3.yandex.net/datasets/orders.csv')
#  чтение данных из csv-файла в датафрейм и сохранение в переменную ‘orders_original’
# abnormal_orders = orders_original.query('visitorId in @unique_ab')
# фильтрация строк в датафрейме ‘orders_original’ с условием, что значения столбца ‘visitorId’ входят в ‘unique_ab’

# abnormal_orders_by_visitors = (abnormal_orders.groupby('visitorId', as_index=False).agg({'transactionId': 'nunique'}))
# группировка данных по столбцу ‘visitorId’
# подсчёт уникальных значений столбца ‘transactionId’ по сгрупированным данным
# сохранение результата в переменной ‘abnormal_orders_by_visitors’

# abnormal_orders_by_visitors.columns = ['visitor_id', 'orders']
# присваивание названий столбцам таблицы ‘abnormal_orders_by_visitors’

# x_values = pd.Series(range(0, len(abnormal_orders_by_visitors)))
# серия из чисел от 0 до количества наблюдений в ‘abnormal_orders_by_visitors’

# plt.figure(figsize=(18, 4))
# установка размера графика

# plt.scatter(x_values, abnormal_orders_by_visitors['orders'])
# построение точечной диаграммы числа заказов на одного пользователя
# передача значений переменной ‘x_values’ для горизонтальной оси
# передача значений столбца ‘orders’ датафрейма ‘abnormal_orders_by_visitors’ для вертикальной оси

# plt.title('Распределение количества заказов по пользователям, попавшим одновременно в обе группы A/B-теста', 
          # fontsize=12)
# установка заголовка для графика

# plt.xlabel('Количество пользователей, попавших одновременно в обе группы A/B-теста', fontsize=10)
# установка подписи для горизонтальной оси графика

# plt.ylabel('Количество заказов', fontsize=10)
# установка подписи для вертикальной оси графика

# abnormal_orders_by_visitors.sort_values(by='orders', ascending=False).head(15)
# сортировка значений датафрейма ‘abnormal_orders_by_visitors’ по убыванию количества заказов пользователей
# вывод на экран первых 15-ти строк

# %%
x_values = pd.Series(range(0, len(orders_by_visitors.query('visitor_id in @unique_ab'))))
# серия из чисел от 0 до количества наблюдений в ‘orders_by_visitors’
# с условием, что значения столбца ‘visitor_id’ входят в ‘unique_ab’

plt.figure(figsize=(18, 4))
# установка размера графика

plt.scatter(x_values, orders_by_visitors.query('visitor_id in @unique_ab')['orders'])
# построение точечной диаграммы числа заказов на одного пользователя
# передача значений переменной ‘x_values’ для горизонтальной оси
# передача значений столбца ‘orders’ датафрейма ‘orders_by_visitors’ для вертикальной оси
# с условием, что значения столбца ‘visitor_id’ входят в ‘unique_ab’

plt.title('Распределение количества заказов по пользователям', 
          fontsize=12)
# установка заголовка для графика

plt.xlabel('Количество пользователей', fontsize=10)
# установка подписи для горизонтальной оси графика

plt.ylabel('Количество заказов', fontsize=10)
# установка подписи для вертикальной оси графика

orders_by_visitors.query('visitor_id in @unique_ab').groupby('orders').agg({'visitor_id': 'count'})
# группировка данных по столбцу ‘orders’ и подсчёт количества уникальных значений ‘visitor_id’ в каждой группе
# с условием, что значения столбца ‘visitor_id’ входят в ‘unique_ab’
# Out:
#         visitor_id
# orders
# 2               35
# 3               10
# 4                3
# 5                6
# 8                1
# 9                1
# 11               2

# %% [markdown]
# Основная часть пользователей, попавших одновременно в обе группы A/B-теста, оформила 2 заказа (35 человек). Меньше тех, кто совершил 3-5 заказов (19 человек). Среди оказавшихся в обеих группах, существует посетитель, заказавший 8 раз, и заказавший 9 раз, а также встречаются два человека, совершивших целых 11 заказов. Это доказывает то, что пользователи, попавшие в группы A и B одновременно, являются аномальными и могут искажать результаты A/B-теста.

# %% [markdown]
# Если дорогой заказ попадёт в одну из групп теста, он исказит результаты и сделает победителем ту группу, где оказался. При этом такие покупки — редкость, исключение, которое проявилось не из-за тестирования гипотезы, а случайно.
#
# Построим точечный график стоимостей заказов.

# %%
x_values = pd.Series(range(0, len(orders['revenue'])))
# серия из чисел от 0 до количества наблюдений в столбце ‘revenue’ датафрейма ‘orders’

plt.figure(figsize=(18, 4))
# установка размера графика

plt.scatter(x_values, orders['revenue'])
# построение точечной диаграммы стоимостей заказов
# передача значений переменной ‘x_values’ для горизонтальной оси
# передача значений столбца ‘revenue’ датафрейма ‘orders’ для вертикальной оси

plt.title('Распределение стоимостей заказов', 
          fontsize=12)
# установка заголовка для графика

plt.xlabel('Количество заказов', fontsize=10)
# установка подписи для горизонтальной оси графика

plt.ylabel('Стоимость заказа', fontsize=10)
# установка подписи для вертикальной оси графика

orders.sort_values(by='revenue', ascending=False).head(10)
# сортировка значений датафрейма ‘orders’ по убыванию выручки
# Out:
#       transaction_id  visitor_id       date  revenue group
# 425        590470918  1920142716 2019-08-19  1294500     B
# 1196      3936777065  2108080724 2019-08-15   202740     B
# 858        192721366  1316129916 2019-08-27    93940     A
# 1136       666610489  1307669133 2019-08-13    92550     A
# 744       3668308183   888512513 2019-08-27    86620     B
# 682       1216533772  4266935830 2019-08-29    78990     B
# 662       1811671147  4266935830 2019-08-29    78990     A
# 743       3603576309  4133034833 2019-08-09    67990     A
# 1103      1348774318  1164614297 2019-08-12    66350     A
# 1099       316924019   148427295 2019-08-12    65710     A

# %% [markdown]
# <div class="alert alert-info"> <b>Комментарий студента: </b>
#
# Стоимость почти всех заказов меньше <strike> 93 тысяч </strike> 94 тысяч. Есть выброс — заказ стоимостью 202 тыс. 740. Также существует очень аномальный заказ в интернет-магазине — на 1 млн. 294 тыс. 500.
#
# Построим точечный график стоимостей заказов, исключив 2 заказа с очень высокой стоимостью.
#
# </div>

# %%
x_values = pd.Series(range(0, len(orders.query('revenue < 93000')['revenue'])))
# серия из чисел от 0 до количества наблюдений в столбце ‘revenue’ датафрейма ‘orders’ (без 2-х дорогих заказов)

plt.figure(figsize=(18, 4))
# установка размера графика

plt.scatter(x_values, orders.query('revenue < 93000')['revenue'])
# построение точечной диаграммы стоимостей заказов
# передача значений переменной ‘x_values’ для горизонтальной оси
# передача значений столбца ‘revenue’ датафрейма ‘orders’ (без 2-х дорогих заказов) для вертикальной оси

plt.title('Распределение стоимостей заказов (без 2-х заказов с очень высокой стоимостью)', 
          fontsize=12)
# установка заголовка для графика

plt.xlabel('Количество заказов', fontsize=10)
# установка подписи для горизонтальной оси графика

plt.ylabel('Стоимость заказа', fontsize=10)
# установка подписи для вертикальной оси графика

orders.query('revenue < 93000').sort_values(by='revenue', ascending=False).head(10)
# сортировка значений датафрейма ‘orders’ (без 2-х дорогих заказов) по убыванию выручки
# Out:
#       transaction_id  visitor_id       date  revenue group
# 1136       666610489  1307669133 2019-08-13    92550     A
# 744       3668308183   888512513 2019-08-27    86620     B
# 682       1216533772  4266935830 2019-08-29    78990     B
# 662       1811671147  4266935830 2019-08-29    78990     A
# 743       3603576309  4133034833 2019-08-09    67990     A
# 1103      1348774318  1164614297 2019-08-12    66350     A
# 1099       316924019   148427295 2019-08-12    65710     A
# 949       1347999392   887908475 2019-08-21    60450     A
# 940       2420050534  4003628586 2019-08-08    58550     B
# 1029       469609643  2378935119 2019-08-10    58220     A

# %% [markdown]
# Стоимость большинства заказов не превышает 20 тысяч. Для более точного определения аномальных заказов, посчитаем 95-й и 99-й перцентили стоимости заказов.

# %% [markdown]
# <div class="alert alert-success">
# <h2> Комментарий ревьюера <a class="tocSkip"> </h2>
#
# <b>Отлично!✅:</b> Правильно! Круто, что сделала срез и более подробно рассмотрела заказы.
# </div>

# %%
print(np.percentile(orders['revenue'], [95, 99]))
# вычисление 95-го и 99-го процентилей списка значений столбца ‘revenue’ датафрейма ‘orders’
# Out:
# [28000.  58233.2]

# %% [markdown]
# <div class="alert alert-info"> <b>Комментарий студента: </b>
#
# Не более 5% заказов дороже <strike> 26 тыс. 785 </strike>  28 тыс. и не более 1% дороже <strike> 53 тыс. 904. </strike> 58 тыс. 233.
#
# Будем считать аномальными заказами те, что дороже 30 тыс.
#
# </div>

# %% [markdown]
# <div class="alert alert-success">
# <h2> Комментарий ревьюера <a class="tocSkip"> </h2>
#
# <b>Отлично!✅:</b> Замечательное решение, молодец!
# </div>

# %% [markdown]
# ### Подсчёт статистической значимости различий в среднем количестве заказов на посетителя и в среднем чеке заказа между группами по «сырым» данным

# %% [markdown]
# Посчитаем статистическую значимость различий в среднем количестве заказов на посетителя между группами по «сырым» данным — без удаления аномальных пользователей.
#
# Сформулируем гипотезы.
#
# - Нулевая гипотеза: различий в среднем количестве заказов между группами нет.
# - Альтернативная гипотеза: различия в среднем количестве заказов между группами есть.
#
# Создадим переменные `orders_by_visitors_a` и `orders_by_visitors_b` со столбцами `visitor_id`, `orders`. В них для пользователей, которые заказывали хотя бы 1 раз, укажем число совершённых заказов.

# %% [markdown]
# <div class="alert alert-success">
# <h2> Комментарий ревьюера <a class="tocSkip"> </h2>
#
# <b>Отлично!✅:</b> Гипотезы сформулированы верно!
# </div>

# %%
orders_by_visitors_a = (
    orders[orders['group'] == 'A'].groupby('visitor_id', as_index=False).agg({'transaction_id': pd.Series.nunique}))
# выбор подмножества датафрейма ‘orders’, где значение столбца ‘group’ равно ‘A’
# группировка данных по столбцу ‘visitor_id’
# подсчёт уникальных значений столбца ‘transaction_id’ по сгрупированным данным
# сохранение результата в переменной ‘orders_by_visitors_a’

orders_by_visitors_a.columns = ['visitor_id', 'orders']
# присваивание названий столбцам таблицы ‘orders_by_visitors_a’

orders_by_visitors_b = (
    orders[orders['group'] == 'B'].groupby('visitor_id', as_index=False).agg({'transaction_id': pd.Series.nunique}))
# выбор подмножества датафрейма ‘orders’, где значение столбца ‘group’ равно ‘B’
# группировка данных по столбцу ‘visitor_id’
# подсчёт уникальных значений столбца ‘transaction_id’ по сгрупированным данным
# сохранение результата в переменной ‘orders_by_visitors_b’

orders_by_visitors_b.columns = ['visitor_id', 'orders']
# присваивание названий столбцам таблицы ‘orders_by_visitors_b’

# %% [markdown]
# Объявим переменные `sample_a` и `sample_b`, в которых пользователям из разных групп будет соответствовать количество заказов. Тем, кто ничего не заказал, будут соответствовать нули. Это нужно, чтобы подготовить выборки к проверке критерием Манна-Уитни.

# %%
visitors_a_daily = visitors[visitors['group'] == 'A'][['date', 'visitors']]
# создание датафрейма ‘visitors_a_daily’, содержащего только те строки из исходного датафрейма ‘visitors’, 
# где значение столбца group равно ‘A’
# выбор столбцов ‘date’ и ‘visitors’, которые будут сохранены в новом датафрейме
# получение количества пользователей в выбранную дату в группе A

visitors_a_daily.columns = ['date', 'visitors_per_date_a']
# присваивание названий столбцам датафрейма ‘visitors_a_daily’

sample_a = pd.concat(
    [orders_by_visitors_a['orders'], pd.Series(
        0, index=np.arange(
            visitors_a_daily['visitors_per_date_a'].sum() - len(orders_by_visitors_a['orders'])), name='orders')], axis=0)
# объединение 2-х объектов Series: кол-ва заказов для каждого из пользователей группы A и нулей для пользователей группы A, 
# которые ничего не заказывали
# количество нулей равно разнице между суммой посетителей и количеством записей о заказах
# передача аргумента, сообщающего, что объекты Series нужно объединить по строкам (то есть записать подряд)

visitors_b_daily = visitors[visitors['group'] == 'B'][['date', 'visitors']]
# создание датафрейма ‘visitors_b_daily’, содержащего только те строки из исходного датафрейма ‘visitors’, 
# где значение столбца group равно ‘B’
# выбор столбцов ‘date’ и ‘visitors’, которые будут сохранены в новом датафрейме
# получение количества пользователей в выбранную дату в группе B

visitors_b_daily.columns = ['date', 'visitors_per_date_b']
# присваивание названий столбцам датафрейма ‘visitors_b_daily’

sample_b = pd.concat(
    [orders_by_visitors_b['orders'], pd.Series(
        0, index=np.arange(
            visitors_b_daily['visitors_per_date_b'].sum() - len(orders_by_visitors_b['orders'])), name='orders')], axis=0)
# объединение 2-х объектов Series: кол-ва заказов для каждого из пользователей группы B и нулей для пользователей группы B, 
# которые ничего не заказывали
# количество нулей равно разнице между суммой посетителей и количеством записей о заказах
# передача аргумента, сообщающего, что объекты Series нужно объединить по строкам (то есть записать подряд)

# %% [markdown]
# Посчитаем статистическую значимость различия среднего количества заказов на пользователя между группами по «сырым» данным. Применим тест Манна-Уитни. Выведем p-value для сравнения среднего между группами. Будем использовать значение 0.05 в качестве уровня статистической значимости.
#
# Кроме того, вычислим и выведем среднее число заказов на пользователя группы A и группы B, а также относительное различие в среднем между группами A/B-теста по «сырым» данным.

# %%
alpha = 0.05
# создание переменной ‘alpha’, равной 0.05, для установки уровня статистической значимости

pvalue = stats.mannwhitneyu(sample_a, sample_b)[1]
# подсчёт статистической значимости различия среднего количества заказов между группами
# применение теста Манна-Уитни

print(f'p-value: {"{0:.3f}".format(pvalue)}')
# вывод p-value для сравнения среднего между группами 
# округление p-value до 3-х знаков после запятой

if pvalue < alpha:
    print('Отвергаем нулевую гипотезу')
else:
    print('Нет оснований отвергнуть нулевую гипотезу')
# проверка, меньше ли p-значение результатов исследования, чем уровень значимости
# если это так, то нулевая гипотеза отвергается и выводится соответствующее сообщение
# в противном случае выводится ссобщение о том, что нет оснований отвергнуть нулевую гипотезу

print('Среднее число заказов на пользователя группы А по «сырым» данным:', "{:.3f}".format(sample_a.mean()))
# вычисление среднего значения в выборке ‘sample_a’
# округление до 3-х знаков после запятой

print('Среднее число заказов на пользователя группы B по «сырым» данным:', "{:.3f}".format(sample_b.mean()))
# вычисление среднего значения в выборке ‘sample_b’
# округление до 3-х знаков после запятой

print('Относительное различие среднего кол-ва заказов на посетителя между группами по «сырым» данным:', 
      "{0:.2%}".format(sample_b.mean() / sample_a.mean() - 1))
# вычисление и вывод относительного различия в среднем между группами
# округление до 2-х знаков после запятой
# Out:
# p-value: 0.017
# Отвергаем нулевую гипотезу
# Среднее число заказов на пользователя группы А по «сырым» данным: 0.030
# Среднее число заказов на пользователя группы B по «сырым» данным: 0.034
# Относительное различие среднего кол-ва заказов на посетителя между группами по «сырым» данным: 13.81%

# %% [markdown]
# <div class="alert alert-info"> <b>Комментарий студента: </b>
#
# P-value составляет <strike> 0.011 </strike> 0.017, что меньше заданного уровня значимости, равного 0.05, поэтому нулевую гипотезу отвергаем. По «сырым» данным можно сделать вывод, что в среднем количестве заказов на посетителя между группами A/B-теста есть статистически значимые различия. Относительный прирост среднего числа заказов группы B к конверсии группы A равен <strike> 15.9%. </strike> 13.8%.
#
# </div>

# %% [markdown]
# <div class="alert alert-success">
# <h2> Комментарий ревьюера <a class="tocSkip"> </h2>
#
# <b>Отлично!✅:</b> Хорошо!
# </div>

# %% [markdown]
# Посчитаем статистическую значимость различий в среднем чеке заказа между группами по «сырым» данным.
#
# - Нулевая гипотеза: различий в среднем чеке между группами нет.
# - Альтернативная гипотеза: различия в среднем чеке между группами есть.
#
# Чтобы рассчитать статистическую значимость различий в среднем чеке, передадим критерию Манна-Уитни данные о выручке с заказов. Будем использовать значение 0.05 в качестве уровня статистической значимости.
#
# А ещё найдём средние чеки групп A и B, а также относительное различие в среднем чеке между группами A/B-теста по «сырым» данным.

# %%
pvalue = stats.mannwhitneyu(orders[orders['group'] == 'A']['revenue'], orders[orders['group'] == 'B']['revenue'])[1]
# подсчёт статистической значимости различия средних чеков между группами
# применение теста Манна-Уитни

print(f'p-value: {"{0:.3f}".format(pvalue)}')
# вывод p-value для сравнения средних чеков между группами 
# округление p-value до 3-х знаков после запятой

if pvalue < alpha:
    print('Отвергаем нулевую гипотезу')
else:
    print('Нет оснований отвергнуть нулевую гипотезу')
# проверка, меньше ли p-значение результатов исследования, чем уровень значимости
# если это так, то нулевая гипотеза отвергается и выводится соответствующее сообщение
# в противном случае выводится ссобщение о том, что нет оснований отвергнуть нулевую гипотезу

print('Средний чек заказа группы A по «сырым» данным:', 
      "{0:.2f}".format(orders[orders['group'] == 'A']['revenue'].mean()))
# вывод среднего чека группы A
# округление результата до 2-х знаков после запятой

print('Средний чек заказа группы B по «сырым» данным:',
      "{0:.2f}".format(orders[orders['group'] == 'B']['revenue'].mean()))
# вывод среднего чека группы B
# округление результата до 2-х знаков после запятой

print('Относительное различие в среднем чеке между группами A/B-теста по «сырым» данным:',
    "{0:.2%}".format(
        orders[orders['group'] == 'B']['revenue'].mean() / orders[orders['group'] == 'A']['revenue'].mean() - 1))
# вывод относительного прироста среднего чека группы B
# округление результата до 2-х знаков после запятой
# Out:
# p-value: 0.729
# Нет оснований отвергнуть нулевую гипотезу
# Средний чек заказа группы A по «сырым» данным: 7333.58
# Средний чек заказа группы B по «сырым» данным: 9230.88
# Относительное различие в среднем чеке между группами A/B-теста по «сырым» данным: 25.87%

# %% [markdown]
# <div class="alert alert-info"> <b>Комментарий студента: </b>
#
# P-value составляет <strike> 0.829 </strike> 0.729, что значительно больше заданного уровня значимости, равного 0.05. Значит, причин отвергать нулевую гипотезу и считать, что в среднем чеке между группами A/B-теста по «сырым» данным есть статистически значимые различия, нет. При этом средний чек группы B <strike> (9 тыс. 250) </strike> (9 тыс. 230) намного выше среднего чека группы A <strike> (7 тыс. 189). </strike> (7 тыс. 333). Относительное различие среднего чека между группами по «сырым» данным равно <strike> 28.6%. </strike> 25.9%.
#
# </div>

# %% [markdown]
# <div class="alert alert-success">
# <h2> Комментарий ревьюера <a class="tocSkip"> </h2>
#
# <b>Отлично!✅:</b> Согласна!
# </div>

# %% [markdown]
# ### Подсчёт статистической значимости различий в среднем количестве заказов на посетителя и в среднем чеке заказа между группами по «очищенным» данным

# %% [markdown]
# <div class="alert alert-info"> <b>Комментарий студента: </b>
#
# Посчитаем статистическую значимость различий в среднем количестве заказов на посетителя и в среднем чеке заказа между группами по «очищенным» данным.
#
# Найденные ранее 95-й и 99-й перцентили средних чеков равны <strike> 26 тыс. 785 и 53 тыс. 904 </strike> 28 тыс. и 58 тыс. 233. А 95-й и 99-й перцентили количества заказов на одного пользователя равны <strike> одному и двум заказам </strike> двум или четырём заказам на пользователя.
#
# Мы приняли за аномальных пользователей тех, кто совершил 3 заказа или совершил заказ дороже 30 тыс. Так мы уберём <strike> 1% </strike> 5% пользователей с наибольшим числом заказов и от 1% до 5% пользователей с дорогими заказами.
#
# Сделаем срезы пользователей с числом заказов больше 2 — `visitors_with_many_orders` и пользователей, совершивших заказы дороже 30 000 — `visitors_with_expensive_orders`. Объединим их в таблице `abnormal_visitors`.
#
# </div>

# %%
# number_of_orders_limit = np.percentile(orders_by_visitors['orders'], 99)
# вычисление 99-го процентиля значений столбца ‘orders’ в датафрейме ‘orders_by_visitors’
# задание границы количества заказов

number_of_orders_limit = np.percentile(orders_by_visitors['orders'], 95)
# вычисление 95-го процентиля значений столбца ‘orders’ в датафрейме ‘orders_by_visitors’
# задание границы количества заказов

visitors_with_many_orders = pd.concat(
    [orders_by_visitors_a[orders_by_visitors_a['orders'] > number_of_orders_limit]['visitor_id'],
        orders_by_visitors_b[orders_by_visitors_b['orders'] > number_of_orders_limit]['visitor_id'],],
    axis=0)
# объединение посетителей, 
# у которых количество заказов превышает заданное ограничение

# order_value_limit = round(np.percentile(orders['revenue'], 95.905))
# вычисление 95.905-го процентиля значений столбца ‘revenue’ в датафрейме ‘orders’
# задание границы стоимости заказа

order_value_limit = round(np.percentile(orders['revenue'], 95.5214))
# вычисление 95.5214-го процентиля значений столбца ‘revenue’ в датафрейме ‘orders’
# задание границы стоимости заказа

visitors_with_expensive_orders = orders[orders['revenue'] > order_value_limit]['visitor_id']
# отбор посетителей, у которых есть дорогие заказы (где выручка больше заданного ограничения)

abnormal_visitors = (pd.concat([visitors_with_many_orders, visitors_with_expensive_orders], axis=0)
    .drop_duplicates()
    .sort_values())
# объединение в таблице ‘abnormal_visitors’ пользователей с числом заказов больше 2 
# и пользователей, совершивших заказы дороже 30 000
# удаление дубликатов, сортировка значений по возрастанию

abnormal_visitors.head(5).to_frame()
# вывод первых 5-ти строк переменной ‘abnormal_visitors’
# Out:
#       visitor_id
# 1099   148427295
# 18     199603092
# 928    204675465
# 23     237748145
# 37     249864742

# %% [markdown]
# Узнаем, сколько всего аномальных пользователей.

# %%
print('Количество аномальных пользователей:', abnormal_visitors.shape[0], 'человек')
# получение количества строк в таблице ‘abnormal_visitors’
# Out:
# Количество аномальных пользователей: 68 человек

# %% [markdown]
# <div class="alert alert-info"> <b>Комментарий студента: </b>
#
# Всего <strike> 49 </strike> 68 аномальных пользователей. Узнаем, как их действия повлияли на результаты теста. Посчитаем статистическую значимость различий в среднем количестве заказов между группами теста по «очищенным» данным — после удаления аномальных пользователей.
#
# - Нулевая гипотеза: различий в среднем количестве заказов между группами нет.
# - Альтернативная гипотеза: различия в среднем количестве заказов между группами есть.
#
# Сначала подготовим выборки количества заказов по пользователям по группам A/B-теста.
#
# </div>

# %%
sample_a_filtered = pd.concat(
    [
        orders_by_visitors_a[
            np.logical_not(orders_by_visitors_a['visitor_id'].isin(abnormal_visitors))
        ]['orders'],
        pd.Series(
            0,
            index=np.arange(
                visitors_a_daily['visitors_per_date_a'].sum() - len(orders_by_visitors_a['orders'])
            ),
            name='orders',
        ),
    ],
    axis=0)
# объединение 2-х объектов Series: кол-ва заказов для каждого из пользователей группы A и нулей для пользователей группы A, 
# которые ничего не заказывали 
# количество нулей равно разнице между суммой посетителей и количеством записей о заказах
# с исключением аномальных пользователей

sample_b_filtered = pd.concat(
    [
        orders_by_visitors_b[
            np.logical_not(orders_by_visitors_b['visitor_id'].isin(abnormal_visitors))
        ]['orders'],
        pd.Series(
            0,
            index=np.arange(
                visitors_b_daily['visitors_per_date_b'].sum() - len(orders_by_visitors_b['orders'])
            ),
            name='orders',
        ),
    ],
    axis=0)
# объединение 2-х объектов Series: кол-ва заказов для каждого из пользователей группы B и нулей для пользователей группы B, 
# которые ничего не заказывали 
# количество нулей равно разнице между суммой посетителей и количеством записей о заказах
# с исключением аномальных пользователей

# %% [markdown]
# Применим статистический критерий Манна-Уитни к полученным выборкам `sample_a_filtered` и `sample_b_filtered`.
#
# Будем использовать значение 0.05 в качестве уровня статистической значимости.

# %%
pvalue = stats.mannwhitneyu(sample_a_filtered, sample_b_filtered)[1]
# подсчёт статистической значимости различия среднего количества заказов между группами
# применение теста Манна-Уитни

print(f'p-value: {"{0:.3f}".format(pvalue)}')
# вывод p-value для сравнения среднего между группами 
# округление p-value до 3-х знаков после запятой

if pvalue < alpha:
    print('Отвергаем нулевую гипотезу')
else:
    print('Нет оснований отвергнуть нулевую гипотезу')
# проверка, меньше ли p-значение результатов исследования, чем уровень значимости
# если это так, то нулевая гипотеза отвергается и выводится соответствующее сообщение
# в противном случае выводится ссобщение о том, что нет оснований отвергнуть нулевую гипотезу

print('Среднее число заказов на пользователя группы А по «очищенным» данным:', "{:.3f}".format(sample_a_filtered.mean()))
# вычисление среднего значения в выборке ‘sample_a_filtered’
# округление до 3-х знаков после запятой

print('Среднее число заказов на пользователя группы B по «очищенным» данным:', "{:.3f}".format(sample_b_filtered.mean()))
# вычисление среднего значения в выборке ‘sample_b_filtered’
# округление до 3-х знаков после запятой

print('Относительное различие среднего кол-ва заказов на посетителя между группами по «очищенным» данным:', 
      "{0:.2%}".format(sample_b_filtered.mean() / sample_a_filtered.mean() - 1))
# вычисление и вывод относительного различия в среднем между группами
# округление до 2-х знаков после запятой
# Out:
# p-value: 0.013
# Отвергаем нулевую гипотезу
# Среднее число заказов на пользователя группы А по «очищенным» данным: 0.025
# Среднее число заказов на пользователя группы B по «очищенным» данным: 0.030
# Относительное различие среднего кол-ва заказов на посетителя между группами по «очищенным» данным: 17.16%

# %% [markdown]
# <div class="alert alert-info"> <b>Комментарий студента: </b>
#
# Как и в случае с «сырыми» данными, статистическая значимость достигнута. Группа B лучше группы A.
#
# P-value составляет <strike> 0.01 </strike> 0.013, что меньше заданного уровня значимости, равного 0.05. Значит, нулевую гипотезу о том, что статистически значимых различий в среднем числе заказов между группами нет, отвергаем. По «очищенным» данным можно сделать вывод, что в среднем количестве заказов на посетителя между группами A/B-теста есть статистически значимые различия. Относительный выигрыш группы B по «очищенным» данным равен <strike> 18.7% </strike> 17.2%, что на <strike> 2.8% </strike> 3.4% больше, чем по «сырым» данным.
#
# Посчитаем статистическую значимость различий в среднем чеке заказа между группами по «очищенным» данным. Будем использовать значение 0.05 в качестве уровня статистической значимости.
#
# - Нулевая гипотеза: различий в среднем чеке между группами нет.
# - Альтернативная гипотеза: различия в среднем чеке между группами есть.
#
# </div>

# %% [markdown]
# <div class="alert alert-success">
# <h2> Комментарий ревьюера <a class="tocSkip"> </h2>
#
# <b>Отлично!✅:</b> Супер, двигаемся дальше!
# </div>

# %%
pvalue = stats.mannwhitneyu(orders[
                np.logical_and(
                    orders['group'] == 'A',
                    np.logical_not(orders['visitor_id'].isin(abnormal_visitors)),
                )
            ]['revenue'],
            orders[
                np.logical_and(
                    orders['group'] == 'B',
                    np.logical_not(orders['visitor_id'].isin(abnormal_visitors)),
                )
            ]['revenue'])[1]
# подсчёт статистической значимости различия средних чеков между группами
# применение теста Манна-Уитни

print(f'p-value: {"{0:.3f}".format(pvalue)}')
# вывод p-value для сравнения средних чеков между группами 
# округление p-value до 3-х знаков после запятой

if pvalue < alpha:
    print('Отвергаем нулевую гипотезу')
else:
    print('Нет оснований отвергнуть нулевую гипотезу')
# проверка, меньше ли p-значение результатов исследования, чем уровень значимости
# если это так, то нулевая гипотеза отвергается и выводится соответствующее сообщение
# в противном случае выводится ссобщение о том, что нет оснований отвергнуть нулевую гипотезу

print('Средний чек заказа группы A по «очищенным» данным:', 
      "{0:.2f}".format(orders[
            np.logical_and(
                orders['group'] == 'A',
                np.logical_not(orders['visitor_id'].isin(abnormal_visitors)),
            )
        ]['revenue'].mean()))
# вывод среднего чека группы A
# округление результата до 2-х знаков после запятой

print('Средний чек заказа группы B по «очищенным» данным:',
      "{0:.2f}".format(orders[
            np.logical_and(
                orders['group'] == 'B',
                np.logical_not(orders['visitor_id'].isin(abnormal_visitors)),
            )
        ]['revenue'].mean()))
# вывод среднего чека группы B
# округление результата до 2-х знаков после запятой

print('Относительное различие в среднем чеке между группами A/B-теста по «очищенным» данным:',
    "{0:.2%}".format(
        orders[
            np.logical_and(
                orders['group'] == 'B',
                np.logical_not(orders['visitor_id'].isin(abnormal_visitors)),
            )
        ]['revenue'].mean()
        / orders[
            np.logical_and(
                orders['group'] == 'A',
                np.logical_not(orders['visitor_id'].isin(abnormal_visitors)),
            )
        ]['revenue'].mean()
        - 1))
# вывод относительного прироста среднего чека группы B
# округление результата до 2-х знаков после запятой
# Out:
# p-value: 0.720
# Нет оснований отвергнуть нулевую гипотезу
# Средний чек заказа группы A по «очищенным» данным: 5314.82
# Средний чек заказа группы B по «очищенным» данным: 5192.04
# Относительное различие в среднем чеке между группами A/B-теста по «очищенным» данным: -2.31%

# %% [markdown]
# <div class="alert alert-info"> <b>Комментарий студента: </b>
#
# По «очищенным» данным p-value меньше на <strike> 0.088 </strike> 0.009, чем p-value по «сырым» данным, и составляет <strike> 0.741 </strike> 0.72, что всё равно намного больше заданного уровня значимости, равного 0.05. В связи с этим, нет оснований отвергать нулевую гипотезу и считать, что в среднем чеке между группами A/B-теста по «очищенным» данным есть статистически значимые различия. По данным без аномальных пользователей средний чек группы B <strike> (5 тыс. 126) </strike> (5 тыс. 192) чуть ниже среднего чека группы A <strike> (5 тыс. 266). </strike> (5 тыс. 315). Относительное различие среднего чека между группами по «очищенным» данным равно <strike> -2.66%. </strike> -2.31%.
#
# </div>

# %% [markdown]
# <div class="alert alert-success">
# <h2> Комментарий ревьюера <a class="tocSkip"> </h2>
#
# <b>Отлично!✅:</b> Отлично!
# </div>

# %% [markdown]
# ### Вывод

# %% [markdown]
# <div class="alert alert-info"> <b>Комментарий студента: </b>
#
# Несмотря на то, что выводы по принятию или отвержению нулевой гипотезы не изменились после удаления аномальных пользователей, мы убедились, что аномалии могут оказывать сильное влияние на результаты A/B-теста.
#
# Подведём итоги анализа A/B-теста:
#
# - Есть статистически значимое различие по среднему количеству заказов на посетителя между группами A/B-теста как по «сырым» данным, так и после фильтрации аномалий.
#
# - Относительный прирост среднего числа заказов группы B к конверсии группы A по «очищенным» данным равен <strike> 18.7% </strike> 17.2%, что на <strike> 2.8% </strike> 3.4% больше, чем по «сырым» данным.
#
# - Нет статистически значимого различия по среднему чеку между группами ни по «сырым», ни по данным после фильтрации аномалий.
#
# - По «сырым» данным средний чек группы B намного выше среднего чека группы A — относительное различие равно <strike> 28.6%. </strike> 25.9%. По «очищенным» данным средний чек группы B чуть ниже среднего чека группы A — относительное различие равно <strike> -2.66%. </strike> -2.31%.
#
# - График различия среднего количества заказов на посетителя между группами говорит о том, что результаты группы B лучше группы A: почти с самого начала теста группа B лидирует по кумулятивному среднему количеству заказов на посетителя, к концу эксперимента группа B зафиксировалась около прироста в <strike> 14-16% </strike> 13.8% относительно группы A.
#
# - На графике различия среднего чека можно наблюдать резкие скачки, что свидетельствует о совершении аномальных заказов. Ближе к концу теста график стал более стабильным, и средний чек группы B до конца теста был выше, чем средний чек группы A. В последний день эксперимента разница среднего чека между группами составила <strike> 28.6%. </strike> 25.9%.
#
# Если стоит вопрос, внедрять изменения или нет, то можно остановить тест и зафиксировать победу группы B. Среднее число заказов на посетителя группы B лучше группы A. Различие по конверсии между группами статистически значимо. Также при наличии возможности можно продолжить A/B-тестирование и проследить за разницей средних чеков групп A и B, так как на данный момент не существует статистически значимого различия по этому показателю между группами.
#
# </div>

# %% [markdown]
# <div class="alert alert-success">
# <h2> Комментарий ревьюера <a class="tocSkip"> </h2>
#
# <b>Отлично!✅:</b> Решение на этом шаге является полностью правильным. Ты здорово разобралась во влиянии выбросов на результаты сравнения средних значений и отметила преимущество статистического теста при интерпретации результатов.
# </div>

# %% [markdown]
# ## Общие выводы

# %% [markdown]
# <div class="alert alert-info"> <b>Комментарий студента: </b>
#
# Нами была проведена подготовка данных к исследованию, приоритизация гипотез по увеличению выручки интернет-магазина и анализ результатов A/B-теста.
#
# В ходе предобработки было установлено, что в данных с гипотезами, посетителями и заказами отсутствуют пропуски, а также явные дубликаты. Было выяснено, что 58 уникальных пользователей попали одновременно в обе группы A/B-теста. <strike> Так как это небольшая доля (5.6%) от общего числа уникальных посетителей интернет-магазина, пользователи, принадлежащие сразу и группе A и группе B, были удалены из таблицы с заказами, чтобы результаты теста не были искажены. </strike> Были приведены к «змеиному» регистру названия столбцов датафреймов. Значения столбцов датафреймов с датами были преобразованы из строкового формата в формат даты.
#
# Были приоритизированы 9 гипотез по увеличению выручки интернет-магазина для максимизации ожидаемого улучшения ключевых метрик бизнеса. Приоритизация осуществлялась двумя способами: с применением фреймворков ICE и RICE. Наиболее перспективной по ICE является гипотеза «Запустить акцию, дающую скидку на товар в день рождения» (ICE равен 16.2). Данная гипотеза получила 9 баллов из 10 при оценке влияния на пользователей и уверенности в гипотезе и 5 баллов по затратам ресурсов на проверку гипотезы. Однако у гипотезы, связанной со скидкой на товар в день рождения, охват пользователей равен 1 баллу, поэтому он не оказал влияния на RICE (равен 16.2). Причиной низкого охвата пользователей может являться то, что среди посетителей магазина мало тех, кто является именинником при покупке товаров, так как день рождения бывает только один раз в году. Некоторые пользователи могут не успеть или не захотеть воспользоваться скидкой в день рождения. К более приоритетным по ICE можно также отнести следующие гипотезы: «Добавить два новых канала привлечения трафика, что позволит привлекать на 30% больше пользователей» (ICE равен 13.3) и «Добавить форму подписки на все основные страницы, чтобы собрать базу клиентов для email-рассылок» (ICE равен 11.2). Добавление параметра, связанного с охватом пользователей, привело к изменению приоритетов гипотез по увеличению выручки интернет-магазина. По RICE самая перспективная гипотеза — это «Добавить форму подписки на все основные страницы, чтобы собрать базу клиентов для email-рассылок» (RICE равен 112). В 2 раза меньше RICE (равен 56) у гипотезы «Добавить блоки рекомендаций товаров на сайт интернет магазина, чтобы повысить конверсию и средний чек заказа». Третье место по приоритету (RICE равен 40) занимают две гипотезы — «Добавить два новых канала привлечения трафика, что позволит привлекать на 30% больше пользователей» и «Показать на главной странице баннеры с актуальными акциями и распродажами, чтобы увеличить конверсию».
#
# У наиболее приоритетной по RICE и входящей в топ-3 по приоритету по ICE гипотезы «Добавить форму подписки на все основные страницы, чтобы собрать базу клиентов для email-рассылок» охват пользователей оценён в 10 баллов из 10, влияние на пользователей — в 7 баллов, уверенность в гипотезе — в 8 баллов, затраты ресурсов на проверку гипотезы — в 5 баллов. Форма подписки может быть размещена на всех основных страницах сайта, что обеспечит максимальный охват пользователей. Могут быть получены целевые подписчики, заинтересованные в продуктах интернет-магазина. Они могут стать частью сообщества, что укрепит связь с брендом и увеличит лояльность. Рассылка новостей, статей и специальных предложений поможет поддерживать интерес аудитории и стимулировать её к совершению покупок.
#
# Нами был проведён A/B-тест и проанализированы его результаты. В группу A вошли 445 посетителей интернет-магазина <strike> (46%) </strike> (43.2%), в группу B — 528 посетителей <strike> (54%). </strike> (51.2%), в обе группы сразу — 58 посетителей (5.6%). Эксперимент длился 1 месяц. Участники теста заходили в интернет-магазин с 1 по 31 августа 2019 года.
#
# В самом начале теста более высокая выручка была у группы A, но <strike> вскоре </strike> уже на 2-й день группа B вырвалась вперёд и продолжала лидировать до конца теста. У группы A увеличение выручки происходило равномерно. У группы B с 18 по 19 августа произошёл резкий рост выручки <strike> с 2 млн. 190 тыс. до 3 млн. 620 тыс. </strike> с 2 млн. 686 тыс. до 4 млн. 116 тыс., что указывает на увеличение количества заказов, появление дорогостоящих заказов в выборке. В последний день эксперимента кумулятивная выручка группы A составила <strike> 3 млн. 364 тыс. </strike> 4 млн. 84 тыс., тогда как кумулятивная выручка группы B — <strike> 5 млн. 68 тыс. </strike> 5 млн. 907 тыс.
#
# Значение кумулятивного среднего чека 31 августа у группы A составило <strike> 7 тыс. 189 </strike> 7 тыс. 333, а группы B — <strike> 9 тыс. 250. </strike> 9 тыс. 230. Таким образом, к концу теста средний чек группы B оказался на <strike> 28.6% </strike> 25.9% выше среднего чека группы A.
#
# Значение кумулятивного среднего количества заказов на посетителя на протяжении всего теста, кроме начального периода, было выше у группы B — <strike> 0.03 </strike> 0.033-0.035, чем у группы A — <strike> 0.025 </strike> 0.029-0.03. В конце теста прирост среднего количества заказов на пользователя группы B составил <strike> 15.9% </strike> 13.8% относительно группы A.
#
# Попадание слишком дорогого заказа в одну из групп теста сказывается на его результатах. Стоимость почти всех заказов в интернет-магазине меньше <strike> 93 тыс. </strike> 94 тыс., а стоимость большинства из них не превышает 20 тыс. Не более 5% заказов дороже <strike> 26 тыс. 785 </strike> 28 тыс. и не более 1% дороже <strike> 53 тыс. 904. </strike> 58 тыс. 233. Есть 2 выброса — заказы на 202 тыс. 740 и на 1 млн. 294 тыс. 500.
#
# Пользователи, оформившие много заказов, оказывают сильное влияние на конверсию. Большая часть посетителей интернет-магазина, участвующих в A/B-тестировании, совершала один заказ. Не более 5% пользователей совершали больше <strike> одного заказа </strike> двух заказов, не более 1% — больше <strike> двух </strike> четырёх заказов. Среди пользователей, попавших в группы A и B одновременно, встречаются те, кто сделал заказ 8, 9 и 11 раз.
#
# За аномальных пользователей были приняты те, кто совершил 3 заказа или оформил заказ дороже 30 тыс. Так <strike> был исключён 1% </strike> были исключены 5% пользователей с наибольшим числом заказов, а также от 1% до 5% пользователей с дорогими заказами. Всего было удалено <strike> 49 </strike> 68 аномальных пользователей для получения «очищенных» данных.
#
# Была определена статистическая значимость различий в среднем чеке заказа между группами A и B. Расчёты проводились с учётом аномальных пользователей и после удаления аномалий. По «сырым» данным p-value составил <strike> 82.9% </strike> 72.9%, а по «очищенным» — <strike> 74.1% </strike> 72%, что значительно больше заданного уровня значимости, равного 5%, поэтому в обоих случаях не удалось отвергнуть нулевую гипотезу об отсутствии статистически значимых различий в среднем количестве заказов между группами.
#
# По «сырым» данным средний чек группы B намного выше среднего чека группы A — относительное различие равно <strike> 28.6%. </strike> 25.9%. По «очищенным» данным средний чек группы B чуть ниже среднего чека группы A — относительное различие равно <strike> -2.66%. </strike> -2.31%.
#
# Также была рассчитана статистическая значимость различий в среднем количестве заказов на посетителя между группами A/B-теста без удаления аномальных пользователей и после фильтрации аномалий. По «сырым» данным p-value составил <strike> 1.1% </strike> 1.7%, а по «очищенным» — <strike> 1% </strike> 1.3%, что меньше заданного уровня значимости, равного 5%, поэтому в обоих случаях была отвергнута нулевая и принята альтернативная гипотеза о существовании статистически значимых различий в среднем количестве заказов между группами.
#
# Относительный прирост среднего числа заказов на пользователя группы B к конверсии группы A по «очищенным» данным получился равным <strike> 18.7% </strike> 17.2%, что на <strike> 2.8% </strike> 3.4% больше, чем по «сырым» данным.
#
# Исходя из результатов анализа, A/B-тест можно остановить, признав победу группы B. Конверсия группы B лучше, чем у группы A, и это статистически значимо. При этом стоит обратить внимание на отсутствие статистически значимого различия в среднем чеке заказа между группами, несмотря на то, что «сырым» данным по средний чек группы B выше среднего чека группы A. Если есть время и ресурсы, можно продолжить тестирование и проследить за дальнейшими изменениями данной метрики.
#
# </div>

# %% [markdown]
# <div class="alert alert-success">
# <h2> Комментарий ревьюера <a class="tocSkip"> </h2>
#
# <b>Отлично!✅:</b> Умница, что собрала все данные в общий вывод!
# </div>

# %% [markdown]
# <div style="border:solid Chocolate 2px; padding: 40px">
# Диана, давай подведем итоги. Ты большая молодец, что старалась и проделала такую большую работу. Мне понравилось, что ты наполнила проект развернутыми выводами и наглядно продемонстрировала каждое задание:) Очень хорошая работа получилась!
#
#     Обязательно пиши, если я могу тебе еще чем-то помочь. Удачи!)
#
# ![](https://media.giphy.com/media/xUKrrEnN9I5lnrcSMv/giphy-downsized-large.gif)

# %% [markdown]
# <div class="alert alert-info"> <b>Комментарий студента: </b>
#
# Привет, Евгения! Очень-очень приятные комментарии! Спасибо большое!!! </div>

# %% [markdown]
# <div class="alert alert-success">
# <h2> Комментарий ревьюера v2<a class="tocSkip"> </h2>
#
# <b>Отлично!✅:</b> Диана, привет! Спасибо, что внесла коррективы, даже после одной рекомендации. Отработала не только код, но и все выводы. Благодарю за обратную связь, работа принята, отличных выходных:)
# </div>
